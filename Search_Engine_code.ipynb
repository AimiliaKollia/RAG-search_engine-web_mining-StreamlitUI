# %% [markdown]
# ## Dependencies

# %%
# !pip install qdrant-client sentence-transformers -q rank-bm25 huggingface_hub
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 378.5/378.5 kB 26.9 MB/s eta 0:00:00

# %% [markdown]
# ###Libraries

# %%
import os
import requests
from bs4 import BeautifulSoup
import time
import pandas as pd
import numpy as np
import re
import spacy
import random
from google.colab import files
from sentence_transformers import SentenceTransformer, CrossEncoder
from huggingface_hub import InferenceClient
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline, TextStreamer
import torch
import getpass
from qdrant_client import QdrantClient
from qdrant_client.models import Distance, VectorParams, Batch, PayloadSchemaType
from qdrant_client.models import Filter, FieldCondition, MatchValue, Range
from rank_bm25 import BM25Plus

# %%
# Set random seeds for reproducibility

random.seed(42)
np.random.seed(42)
torch.manual_seed(42)

if torch.cuda.is_available():
    torch.cuda.manual_seed_all(42)

# %% [markdown]
# ###Crawling and Extracting Texts

# %%
# Function to create safe, unique filenames
def safe_filename(name):
    # Replace any non-alphanumeric character with underscore
    name = re.sub(r'[^\w]', '_', name)
    return name

# Function to clean text (remove citation brackets)
def clean_text(text):
    # Remove citation brackets like [1], [2], [3], etc.
    text = re.sub(r'\[\d+\]', '', text)
    return text.strip()

def clean_country(text):
    # 1. Remove citations
    text = re.sub(r'\[.*?\]', '', text)

    # 2. Remove parentheses and content: "Austria (alleged)" -> "Austria"
    text = re.sub(r'\(.*?\)', '', text)

    # 3. Fix (e.g., "UzbekistanKazakhstan" -> "Uzbekistan, Kazakhstan")
    # This regex finds a lowercase letter followed immediately by an uppercase letter
    text = re.sub(r'(?<=[a-z])(?=[A-Z])', ', ', text)

    # 4. Normalize spaces
    text = re.sub(r'\s+', ' ', text).strip()

    # 5. Fix messy commas (e.g., " , United States" -> "United States")
    text = re.sub(r'\s*,\s*', ', ', text) # Ensure ", " spacing
    text = text.strip(' ,')

    return text

# URLs
BASE_URL = "https://en.wikipedia.org"
LIST_URL = "https://en.wikipedia.org/wiki/List_of_serial_killers_by_number_of_victims"

# Custom headers to avoid Wikipedia blocks
HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/130.0.0.0 Safari/537.36"
}

# Create folder for text files
os.makedirs("serial_killers_texts", exist_ok=True)

# Step 1: Get list page
resp = requests.get(LIST_URL, headers=HEADERS)
if resp.status_code != 200:
    raise ConnectionError(f"Failed to fetch page: {resp.status_code}")

soup = BeautifulSoup(resp.text, "html.parser")

# Step 2: Find all wikitable tables
tables = soup.find_all("table", class_="wikitable")
print(f"Found {len(tables)} tables on the page.")

if not tables:
    with open("debug_page.html", "w", encoding="utf-8") as f:
        f.write(resp.text)
    raise ValueError("No tables found.")

# Step 3: Extract table headers and rows (40 rows PER TABLE)
killers = []

for table_idx, table in enumerate(tables):
    print(f"\nProcessing Table {table_idx + 1}...")

    # Get table headers
    headers = []
    header_row = table.find("tr")
    if header_row:
        for th in header_row.find_all("th"):
            headers.append(th.get_text(strip=True))

    # If no headers found, use default
    if not headers:
        headers = ["Name", "Country", "Years active", "Proven victims", "Possible victims", "Notes"]

    # Get table rows (skip header row)
    table_rows = table.find_all("tr")[1:]

    # Counter for this table only
    table_count = 0

    for row in table_rows:
        if table_count >= 40:  # Limit to 30 rows per table
            print(f"  Reached 40 rows for Table {table_idx + 1}")
            break

        cells = row.find_all("td")
        if len(cells) < 1:
            continue

        # Extract name and link from first column
        name_cell = cells[0]
        link_tag = name_cell.find("a", href=True)
        if not link_tag:
            continue

        name = link_tag.get_text(strip=True)
        link = BASE_URL + link_tag["href"]

        # Extract row data based on headers
        row_data = {}
        row_data["Name"] = name
        row_data["Link"] = link
        row_data["Table"] = table_idx + 1  # Track which table this came from

        # Map cell data to headers (starting from index 1 since name is already extracted)
        for idx, cell in enumerate(cells):
            if idx < len(headers):
                header = headers[idx]
                raw_text = cell.get_text(separator=", ", strip=True)

                if "Country" in header:
                    cell_text = clean_country(raw_text)
                else:
                    cell_text = clean_text(raw_text)

                row_data[header] = cell_text

        killers.append(row_data)
        table_count += 1

    print(f"  Extracted {table_count} rows from Table {table_idx + 1}")

print(f"\n{'='*80}")
print(f"Total collected: {len(killers)} killer entries across {len(tables)} tables")
print(f"{'='*80}\n")

# Step 4: Scrape each killer's Wikipedia page and combine with table data
for idx, killer_data in enumerate(killers, 1):
    name = killer_data.get("Name", "Unknown")
    link = killer_data.get("Link", "")
    table_num = killer_data.get("Table", "?")

    print(f"[{idx}/{len(killers)}] Scraping: {name} (Table {table_num})")

    try:
        page_resp = requests.get(link, headers=HEADERS)
        if page_resp.status_code != 200:
            print(f"Failed to fetch {link}")
            continue

        page_soup = BeautifulSoup(page_resp.text, "html.parser")

        # Main content section
        content_div = page_soup.find("div", {"class": "mw-parser-output"})
        if not content_div:
            print(f"No content div found")
            continue

        # Collect only paragraphs (no headings)
        paragraphs = []
        for p in content_div.find_all("p"):
            text_par = clean_text(p.get_text().strip())
            # Filter out short paragraphs and navigation content
            if text_par and len(text_par) > 50:
                paragraphs.append(text_par)

        wiki_content = "\n\n".join(paragraphs)

        # Combine table data with Wikipedia content
        combined_text = []

        for key, value in killer_data.items():
          if key not in ("Link", "Table") and value:
            combined_text.append(f"{key}: {value}")


        # Add Wikipedia page content
        if wiki_content.strip():
            combined_text.append(wiki_content)

        final_text = "\n".join(combined_text)

        # Save to file only if content exists
        if final_text.strip():
            safe_name_file = safe_filename(name)
            file_path = os.path.join("serial_killers_texts", f"{safe_name_file}.txt")
            with open(file_path, "w", encoding="utf-8") as f:
                f.write(final_text)
            print(f"Saved {safe_name_file}.txt")
        else:
            print(f"No wikipedia content for {name}")

        time.sleep(1)  # polite delay

    except Exception as e:
        print(f"Error scraping {name}: {e}")

print("\n" + "="*80)
print("SCRAPING COMPLETED!")
print("="*80)
print(f"Files saved in 'serial_killers_texts' folder")
print(f"Total files: {len([f for f in os.listdir('serial_killers_texts') if f.endswith('.txt')])}")
# Out:
# Found 7 tables on the page.
#
# Processing Table 1...
#   Extracted 34 rows from Table 1
#
# Processing Table 2...
#   Reached 40 rows for Table 2
#   Extracted 40 rows from Table 2
#
# Processing Table 3...
#   Reached 40 rows for Table 3
#   Extracted 40 rows from Table 3
#
# Processing Table 4...
#   Reached 40 rows for Table 4
#   Extracted 40 rows from Table 4
#
# Processing Table 5...
#   Reached 40 rows for Table 5
#   Extracted 40 rows from Table 5
#
# Processing Table 6...
#   Reached 40 rows for Table 6
#   Extracted 40 rows from Table 6
#
# Processing Table 7...
#   Reached 40 rows for Table 7
#   Extracted 40 rows from Table 7
#
# ================================================================================
# Total collected: 274 killer entries across 7 tables
# ================================================================================
#
# [1/274] Scraping: Luis Garavito (Table 1)
# Saved Luis_Garavito.txt
# [2/274] Scraping: Mariam Soulakiotis (Table 1)
# Saved Mariam_Soulakiotis.txt
# [3/274] Scraping: Pedro López (Table 1)
# Saved Pedro_López.txt
# [4/274] Scraping: Javed Iqbal (Table 1)
# Saved Javed_Iqbal.txt
# [5/274] Scraping: Mikhail Popkov (Table 1)
# Saved Mikhail_Popkov.txt
# [6/274] Scraping: Daniel Camargo Barbosa (Table 1)
# Saved Daniel_Camargo_Barbosa.txt
# [7/274] Scraping: Pedro Rodrigues Filho (Table 1)
# Saved Pedro_Rodrigues_Filho.txt
# [8/274] Scraping: Kampatimar Shankariya (Table 1)
# Saved Kampatimar_Shankariya.txt
# [9/274] Scraping: Hoshang Amini (Table 1)
# Saved Hoshang_Amini.txt
# [10/274] Scraping: Yang Xinhai (Table 1)
# Saved Yang_Xinhai.txt
# [11/274] Scraping: Abul Djabar (Table 1)
# Saved Abul_Djabar.txt
# [12/274] Scraping: Samuel Little (Table 1)
# Saved Samuel_Little.txt
# [13/274] Scraping: William Unek (Table 1)
# Saved William_Unek.txt
# [14/274] Scraping: Mohammed Bijeh (Table 1)
# Saved Mohammed_Bijeh.txt
# [15/274] Scraping: Andrei Chikatilo (Table 1)
# Saved Andrei_Chikatilo.txt
# [16/274] Scraping: Anatoly Onoprienko (Table 1)
# Saved Anatoly_Onoprienko.txt
# [17/274] Scraping: Florisvaldo de Oliveira (Table 1)
# Saved Florisvaldo_de_Oliveira.txt
# [18/274] Scraping: Gary Ridgway (Table 1)
# Saved Gary_Ridgway.txt
# [19/274] Scraping: Alexander Pichushkin (Table 1)
# Saved Alexander_Pichushkin.txt
# [20/274] Scraping: Wang Qiang (Table 1)
# Saved Wang_Qiang.txt
# [21/274] Scraping: Ahmad Suradji (Table 1)
# Saved Ahmad_Suradji.txt
# [22/274] Scraping: Raman Raghav (Table 1)
# Saved Raman_Raghav.txt
# [23/274] Scraping: Moses Sithole (Table 1)
# Saved Moses_Sithole.txt
# [24/274] Scraping: Serhiy Tkach (Table 1)
# Saved Serhiy_Tkach.txt
# [25/274] Scraping: Gennady Mikhasevich (Table 1)
# Saved Gennady_Mikhasevich.txt
# [26/274] Scraping: Hadj Mohammed Mesfewi (Table 1)
# Saved Hadj_Mohammed_Mesfewi.txt
# [27/274] Scraping: Vera Renczi (Table 1)
# Saved Vera_Renczi.txt
# [28/274] Scraping: Fernando Hernández Leyva (Table 1)
# Saved Fernando_Hernández_Leyva.txt
# [29/274] Scraping: Toregeldy Zharambaev (Table 1)
# Saved Toregeldy_Zharambaev.txt
# [30/274] Scraping: John Wayne Gacy (Table 1)
# Saved John_Wayne_Gacy.txt
# [31/274] Scraping: Ali Asghar Borujerdi (Table 1)
# Saved Ali_Asghar_Borujerdi.txt
# [32/274] Scraping: Vasili Komaroff (Table 1)
# Saved Vasili_Komaroff.txt
# [33/274] Scraping: Ramadan Abdel Rehim Mansour (Table 1)
# Saved Ramadan_Abdel_Rehim_Mansour.txt
# [34/274] Scraping: Radik Tagirov (Table 1)
# Saved Radik_Tagirov.txt
# [35/274] Scraping: Karl Denke (Table 2)
# Saved Karl_Denke.txt
# [36/274] Scraping: Francisco das Chagas Rodrigues de Brito (Table 2)
# Saved Francisco_das_Chagas_Rodrigues_de_Brito.txt
# [37/274] Scraping: Monster of the Mangones (Table 2)
# Saved Monster_of_the_Mangones.txt
# [38/274] Scraping: Milton Sipalo (Table 2)
# Saved Milton_Sipalo.txt
# [39/274] Scraping: Luis Gregorio Ramírez Maestre (Table 2)
# Saved Luis_Gregorio_Ramírez_Maestre.txt
# [40/274] Scraping: David Thabo Simelane (Table 2)
# Saved David_Thabo_Simelane.txt
# [41/274] Scraping: Zhang Jun (Table 2)
# Saved Zhang_Jun.txt
# [42/274] Scraping: Cedric Maake (Table 2)
# Saved Cedric_Maake.txt
# [43/274] Scraping: Carl Großmann (Table 2)
# Saved Carl_Großmann.txt
# [44/274] Scraping: Robert Pickton (Table 2)
# Saved Robert_Pickton.txt
# [45/274] Scraping: The Stoneman (Table 2)
# Saved The_Stoneman.txt
# [46/274] Scraping: Juan Corona (Table 2)
# Saved Juan_Corona.txt
# [47/274] Scraping: Fritz Haarmann (Table 2)
# Saved Fritz_Haarmann.txt
# [48/274] Scraping: Béla Kiss (Table 2)
# Saved Béla_Kiss.txt
# [49/274] Scraping: Majid Salek Mohammadi (Table 2)
# Saved Majid_Salek_Mohammadi.txt
# [50/274] Scraping: Yvan Keller (Table 2)
# Saved Yvan_Keller.txt
# [51/274] Scraping: Ronald Dominique (Table 2)
# Saved Ronald_Dominique.txt
# [52/274] Scraping: Juan Fernando Hermosa (Table 2)
# Saved Juan_Fernando_Hermosa.txt
# [53/274] Scraping: Gerald Stano (Table 2)
# Saved Gerald_Stano.txt
# [54/274] Scraping: Earle Nelson (Table 2)
# Saved Earle_Nelson.txt
# [55/274] Scraping: Mikhail Novosyolov (Table 2)
# Saved Mikhail_Novosyolov.txt
# [56/274] Scraping: Manuel Octavio Bermúdez (Table 2)
# Saved Manuel_Octavio_Bermúdez.txt
# [57/274] Scraping: Patrick Kearney (Table 2)
# Saved Patrick_Kearney.txt
# [58/274] Scraping: William Bonin (Table 2)
# Saved William_Bonin.txt
# [59/274] Scraping: Vasile Tcaciuc (Table 2)
# Saved Vasile_Tcaciuc.txt
# [60/274] Scraping: Yoo Young-chul (Table 2)
# Saved Yoo_Young_chul.txt
# [61/274] Scraping: Francisco Guerrero Pérez (Table 2)
# Saved Francisco_Guerrero_Pérez.txt
# [62/274] Scraping: Ted Bundy (Table 2)
# Saved Ted_Bundy.txt
# [63/274] Scraping: Abdullah Shah (Table 2)
# Saved Abdullah_Shah.txt
# [64/274] Scraping: Mohan Kumar (Table 2)
# Saved Mohan_Kumar.txt
# [65/274] Scraping: Bulelani Mabhayi (Table 2)
# Saved Bulelani_Mabhayi.txt
# [66/274] Scraping: Larry Eyler (Table 2)
# Saved Larry_Eyler.txt
# [67/274] Scraping: Cape Town Prostitute Killer (Table 2)
# Saved Cape_Town_Prostitute_Killer.txt
# [68/274] Scraping: ", El Psicópata, " (Table 2)
# Saved ___El_Psicópata___.txt
# [69/274] Scraping: Sergei Ryakhovsky (Table 2)
# Saved Sergei_Ryakhovsky.txt
# [70/274] Scraping: Yevgeny Chuplinsky (Table 2)
# Saved Yevgeny_Chuplinsky.txt
# [71/274] Scraping: M. Jaishankar (Table 2)
# Saved M__Jaishankar.txt
# [72/274] Scraping: Ansis Kaupēns (Table 2)
# Saved Ansis_Kaupēns.txt
# [73/274] Scraping: Vadim Ershov (Table 2)
# Saved Vadim_Ershov.txt
# [74/274] Scraping: Velaphi Ndlangamandla (Table 2)
# Saved Velaphi_Ndlangamandla.txt
# [75/274] Scraping: Carl Eugene Watts (Table 3)
# Saved Carl_Eugene_Watts.txt
# [76/274] Scraping: Belle Gunness (Table 3)
# Saved Belle_Gunness.txt
# [77/274] Scraping: Philipp Tyurin (Table 3)
# Saved Philipp_Tyurin.txt
# [78/274] Scraping: Zdzisław Marchwicki (Table 3)
# Saved Zdzisław_Marchwicki.txt
# [79/274] Scraping: Julio Pérez Silva (Table 3)
# Saved Julio_Pérez_Silva.txt
# [80/274] Scraping: Monster of Florence (Table 3)
# Saved Monster_of_Florence.txt
# [81/274] Scraping: Joachim Kroll (Table 3)
# Saved Joachim_Kroll.txt
# [82/274] Scraping: Arthur Shawcross (Table 3)
# Saved Arthur_Shawcross.txt
# [83/274] Scraping: Naceur Damergi (Table 3)
# Saved Naceur_Damergi.txt
# [84/274] Scraping: Muthukutty Chandran (Table 3)
# Saved Muthukutty_Chandran.txt
# [85/274] Scraping: Marcelo Costa de Andrade (Table 3)
# Saved Marcelo_Costa_de_Andrade.txt
# [86/274] Scraping: Sergey Shipilov (Table 3)
# Saved Sergey_Shipilov.txt
# [87/274] Scraping: Dorángel Vargas (Table 3)
# Saved Dorángel_Vargas.txt
# [88/274] Scraping: Hua Ruizhuo (Table 3)
# Saved Hua_Ruizhuo.txt
# [89/274] Scraping: Denis Pischikov (Table 3)
# Saved Denis_Pischikov.txt
# [90/274] Scraping: Abdufatto Zamanov (Table 3)
# Saved Abdufatto_Zamanov.txt
# [91/274] Scraping: Jeong Nam-gyu (Table 3)
# Saved Jeong_Nam_gyu.txt
# [92/274] Scraping: Amir Qayyum (Table 3)
# Saved Amir_Qayyum.txt
# [93/274] Scraping: Denis Kazungu (Table 3)
# Saved Denis_Kazungu.txt
# [94/274] Scraping: Sararat Rangsiwuthaporn (Table 3)
# Saved Sararat_Rangsiwuthaporn.txt
# [95/274] Scraping: Jake Bird (Table 3)
# Saved Jake_Bird.txt
# [96/274] Scraping: Cleveland Torso Murderer (Table 3)
# Saved Cleveland_Torso_Murderer.txt
# [97/274] Scraping: Kaspars Petrovs (Table 3)
# Saved Kaspars_Petrovs.txt
# [98/274] Scraping: Peter Sutcliffe (Table 3)
# Saved Peter_Sutcliffe.txt
# [99/274] Scraping: Fosaville Serial Killer (Table 3)
# Saved Fosaville_Serial_Killer.txt
# [100/274] Scraping: William Suff (Table 3)
# Saved William_Suff.txt
# [101/274] Scraping: Richard Ramirez (Table 3)
# Saved Richard_Ramirez.txt
# [102/274] Scraping: Sleepy Hollow Killer (Table 3)
# Saved Sleepy_Hollow_Killer.txt
# [103/274] Scraping: Francisco Antonio Laureana (Table 3)
# Saved Francisco_Antonio_Laureana.txt
# [104/274] Scraping: Joseph James DeAngelo (Table 3)
# Saved Joseph_James_DeAngelo.txt
# [105/274] Scraping: Tamara Samsonova (Table 3)
# Saved Tamara_Samsonova.txt
# [106/274] Scraping: Boston Strangler (Table 3)
# Saved Boston_Strangler.txt
# [107/274] Scraping: Herbert Mullin (Table 3)
# Saved Herbert_Mullin.txt
# [108/274] Scraping: Vladimir Storozhenko (Table 3)
# Saved Vladimir_Storozhenko.txt
# [109/274] Scraping: Johannes Mashiane (Table 3)
# Saved Johannes_Mashiane.txt
# [110/274] Scraping: Vasiliy Kulik (Table 3)
# Saved Vasiliy_Kulik.txt
# [111/274] Scraping: Nikolai Dudin (Table 3)
# Saved Nikolai_Dudin.txt
# [112/274] Scraping: Mukosi Freddy Mulaudzi (Table 3)
# Saved Mukosi_Freddy_Mulaudzi.txt
# [113/274] Scraping: Duan Guocheng (Table 3)
# Saved Duan_Guocheng.txt
# [114/274] Scraping: Nikolay Shubin (Table 3)
# Saved Nikolay_Shubin.txt
# [115/274] Scraping: Alexander Spesivtsev (Table 4)
# Saved Alexander_Spesivtsev.txt
# [116/274] Scraping: Charlie Brandt (Table 4)
# Saved Charlie_Brandt.txt
# [117/274] Scraping: Scott Lee Kimball (Table 4)
# Saved Scott_Lee_Kimball.txt
# [118/274] Scraping: Robert Black (Table 4)
# Saved Robert_Black.txt
# [119/274] Scraping: Max Gufler (Table 4)
# Saved Max_Gufler.txt
# [120/274] Scraping: Ernesto Picchioni (Table 4)
# Saved Ernesto_Picchioni.txt
# [121/274] Scraping: Baekuni (Table 4)
# Saved Baekuni.txt
# [122/274] Scraping: Igor Chernat (Table 4)
# Saved Igor_Chernat.txt
# [123/274] Scraping: Ricky Lee Green (Table 4)
# Saved Ricky_Lee_Green.txt
# [124/274] Scraping: Robert Hicks Murray (Table 4)
# Saved Robert_Hicks_Murray.txt
# [125/274] Scraping: William Dean Christensen (Table 4)
# Saved William_Dean_Christensen.txt
# [126/274] Scraping: Angus Sinclair (Table 4)
# Saved Angus_Sinclair.txt
# [127/274] Scraping: John Cooper (Table 4)
# Saved John_Cooper.txt
# [128/274] Scraping: Cary Stayner (Table 4)
# Saved Cary_Stayner.txt
# [129/274] Scraping: Tony Costa (Table 4)
# Saved Tony_Costa.txt
# [130/274] Scraping: Carlton Gary (Table 4)
# Saved Carlton_Gary.txt
# [131/274] Scraping: Oakland County Child Killer (Table 4)
# Saved Oakland_County_Child_Killer.txt
# [132/274] Scraping: Robert Rozier (Table 4)
# Saved Robert_Rozier.txt
# [133/274] Scraping: Leonard Fraser (Table 4)
# Saved Leonard_Fraser.txt
# [134/274] Scraping: Christopher Peterson (Table 4)
# Saved Christopher_Peterson.txt
# [135/274] Scraping: Ricardo Caputo (Table 4)
# Saved Ricardo_Caputo.txt
# [136/274] Scraping: Anthony Allen Shore (Table 4)
# Saved Anthony_Allen_Shore.txt
# [137/274] Scraping: Daytona Beach killer (Table 4)
# Saved Daytona_Beach_killer.txt
# [138/274] Scraping: Jozef Slovák (Table 4)
# Saved Jozef_Slovák.txt
# [139/274] Scraping: Monster of Udine (Table 4)
# Saved Monster_of_Udine.txt
# [140/274] Scraping: John Martin Crawford (Table 4)
# Saved John_Martin_Crawford.txt
# [141/274] Scraping: Oba Chandler (Table 4)
# Saved Oba_Chandler.txt
# [142/274] Scraping: Dallen Bounds (Table 4)
# Saved Dallen_Bounds.txt
# [143/274] Scraping: Wayne Adam Ford (Table 4)
# Saved Wayne_Adam_Ford.txt
# [144/274] Scraping: Heinrich Pommerenke (Table 4)
# Saved Heinrich_Pommerenke.txt
# [145/274] Scraping: Robert Mone (Table 4)
# Saved Robert_Mone.txt
# [146/274] Scraping: Jerry Brudos (Table 4)
# Saved Jerry_Brudos.txt
# [147/274] Scraping: Robert Maudsley (Table 4)
# Saved Robert_Maudsley.txt
# [148/274] Scraping: Aalt Mondria (Table 4)
# Saved Aalt_Mondria.txt
# [149/274] Scraping: Andrew Six (Table 4)
# Saved Andrew_Six.txt
# [150/274] Scraping: Tsutomu Miyazaki (Table 4)
# Saved Tsutomu_Miyazaki.txt
# [151/274] Scraping: Cody Legebokoff (Table 4)
# Saved Cody_Legebokoff.txt
# [152/274] Scraping: Stephen Port (Table 4)
# Saved Stephen_Port.txt
# [153/274] Scraping: Leo Boatman (Table 4)
# Saved Leo_Boatman.txt
# [154/274] Scraping: Howell Donaldson III (Table 4)
# Saved Howell_Donaldson_III.txt
# [155/274] Scraping: Harold Shipman (Table 5)
# Saved Harold_Shipman.txt
# [156/274] Scraping: Niels Högel (Table 5)
# Saved Niels_Högel.txt
# [157/274] Scraping: Baba Anujka (Table 5)
# Saved Baba_Anujka.txt
# [158/274] Scraping: Louay Omar Mohammed al-Taei (Table 5)
# Saved Louay_Omar_Mohammed_al_Taei.txt
# [159/274] Scraping: Donald Harvey (Table 5)
# Saved Donald_Harvey.txt
# [160/274] Scraping: Jane Toppan (Table 5)
# Saved Jane_Toppan.txt
# [161/274] Scraping: Charles Cullen (Table 5)
# Saved Charles_Cullen.txt
# [162/274] Scraping: Stephan Letter (Table 5)
# Saved Stephan_Letter.txt
# [163/274] Scraping: Anders Hansson (Table 5)
# Saved Anders_Hansson.txt
# [164/274] Scraping: Marcel Petiot (Table 5)
# Saved Marcel_Petiot.txt
# [165/274] Scraping: Arnfinn Nesset (Table 5)
# Saved Arnfinn_Nesset.txt
# [166/274] Scraping: Roger Andermatt (Table 5)
# Saved Roger_Andermatt.txt
# [167/274] Scraping: Linda Hazzard (Table 5)
# Saved Linda_Hazzard.txt
# [168/274] Scraping: Maxim Petrov (Table 5)
# Saved Maxim_Petrov.txt
# [169/274] Scraping: Joan Vila Dilmé (Table 5)
# Saved Joan_Vila_Dilmé.txt
# [170/274] Scraping: Vickie Dawn Jackson (Table 5)
# Saved Vickie_Dawn_Jackson.txt
# [171/274] Scraping: Ann Arbor Hospital Killer (Table 5)
# Saved Ann_Arbor_Hospital_Killer.txt
# [172/274] Scraping: Ludivine Chambet (Table 5)
# Saved Ludivine_Chambet.txt
# [173/274] Scraping: Frederick Mors (Table 5)
# Saved Frederick_Mors.txt
# [174/274] Scraping: Elizabeth Wettlaufer (Table 5)
# Saved Elizabeth_Wettlaufer.txt
# [175/274] Scraping: Petr Zelenka (Table 5)
# Saved Petr_Zelenka.txt
# [176/274] Scraping: Marianne Nölle (Table 5)
# Saved Marianne_Nölle.txt
# [177/274] Scraping: Lucy Letby (Table 5)
# Saved Lucy_Letby.txt
# [178/274] Scraping: Orville Lynn Majors (Table 5)
# Saved Orville_Lynn_Majors.txt
# [179/274] Scraping: Efren Saldivar (Table 5)
# Saved Efren_Saldivar.txt
# [180/274] Scraping: Christine Malèvre (Table 5)
# Saved Christine_Malèvre.txt
# [181/274] Scraping: Antoinette Scieri (Table 5)
# Saved Antoinette_Scieri.txt
# [182/274] Scraping: Ahmad Ahmadi (Table 5)
# Saved Ahmad_Ahmadi.txt
# [183/274] Scraping: Kristen Gilbert (Table 5)
# Saved Kristen_Gilbert.txt
# [184/274] Scraping: Frans Hooijmaijers (Table 5)
# Saved Frans_Hooijmaijers.txt
# [185/274] Scraping: Miyuki Ishikawa (Table 5)
# Saved Miyuki_Ishikawa.txt
# [186/274] Scraping: Amy Archer-Gilligan (Table 5)
# Saved Amy_Archer_Gilligan.txt
# [187/274] Scraping: Sonya Caleffi (Table 5)
# Saved Sonya_Caleffi.txt
# [188/274] Scraping: Aino Nykopp-Koski (Table 5)
# Saved Aino_Nykopp_Koski.txt
# [189/274] Scraping: Kimberly Clark Saenz (Table 5)
# Saved Kimberly_Clark_Saenz.txt
# [190/274] Scraping: Kermit Gosnell (Table 5)
# Saved Kermit_Gosnell.txt
# [191/274] Scraping: Edson Izidoro Guimarães (Table 5)
# Saved Edson_Izidoro_Guimarães.txt
# [192/274] Scraping: Michael Swango (Table 5)
# Saved Michael_Swango.txt
# [193/274] Scraping: Richard Angelo (Table 5)
# Saved Richard_Angelo.txt
# [194/274] Scraping: Colin Norris (Table 5)
# Saved Colin_Norris.txt
# [195/274] Scraping: Philadelphia poison ring (Table 6)
# Saved Philadelphia_poison_ring.txt
# [196/274] Scraping: Abboud and Khajawa (Table 6)
# Saved Abboud_and_Khajawa.txt
# [197/274] Scraping: Delfina and María de Jesús González (Table 6)
# Saved Delfina_and_María_de_Jesús_González.txt
# [198/274] Scraping: David Avendaño Ballina, and his followers (Table 6)
# Saved David_Avendaño_Ballina__and_his_followers.txt
# [199/274] Scraping: Hassan Orangi, and Abbas Ali Zarifian (Table 6)
# Saved Hassan_Orangi__and_Abbas_Ali_Zarifian.txt
# [200/274] Scraping: Angel Makers of Nagyrév (Table 6)
# Saved Angel_Makers_of_Nagyrév.txt
# [201/274] Scraping: Long Zhimin, and Yan Shuxia (Table 6)
# Saved Long_Zhimin__and_Yan_Shuxia.txt
# [202/274] Scraping: Ryno-Skachevsky gang (Table 6)
# Saved Ryno_Skachevsky_gang.txt
# [203/274] Scraping: Gang of Amazons (Table 6)
# Saved Gang_of_Amazons.txt
# [204/274] Scraping: Dean Corll, ,, David Owen Brooks, and, Elmer Wayne Henley (Table 6)
# Saved Dean_Corll_____David_Owen_Brooks__and__Elmer_Wayne_Henley.txt
# [205/274] Scraping: Brabant killers (Table 6)
# Saved Brabant_killers.txt
# [206/274] Scraping: Adolfo Constanzo, and, Sara Aldrete (Table 6)
# Saved Adolfo_Constanzo__and__Sara_Aldrete.txt
# [207/274] Scraping: Shankill Butchers (Table 6)
# Saved Shankill_Butchers.txt
# [208/274] Scraping: Viktor Sayenko and Igor Suprunyuk (Table 6)
# Saved Viktor_Sayenko_and_Igor_Suprunyuk.txt
# [209/274] Scraping: Marcelo de Jesus Silva, and his death squad (Table 6)
# Saved Marcelo_de_Jesus_Silva__and_his_death_squad.txt
# [210/274] Scraping: Ripper Crew (Table 6)
# Saved Ripper_Crew.txt
# [211/274] Scraping: John Allen Muhammad, and, Lee Boyd Malvo (Table 6)
# Saved John_Allen_Muhammad__and__Lee_Boyd_Malvo.txt
# [212/274] Scraping: Death Angels (Table 6)
# Saved Death_Angels.txt
# [213/274] Scraping: Vladyslav Volkovich and Volodymyr Kondratenko (Table 6)
# Saved Vladyslav_Volkovich_and_Volodymyr_Kondratenko.txt
# [214/274] Scraping: Lainz Angels of Death (Table 6)
# Saved Lainz_Angels_of_Death.txt
# [215/274] Scraping: The Cleaners (Table 6)
# Saved The_Cleaners.txt
# [216/274] Scraping: José Miculax Bux and Mariano Macú Miculax (Table 6)
# Saved José_Miculax_Bux_and_Mariano_Macú_Miculax.txt
# [217/274] Scraping: Fred West, and, Rosemary West (Table 6)
# Saved Fred_West__and__Rosemary_West.txt
# [218/274] Scraping: Briley Brothers (Table 6)
# Saved Briley_Brothers.txt
# [219/274] Scraping: John Justin Bunting, Robert Joe Wagner and James Spyridon Vlassakis (Table 6)
# Saved John_Justin_Bunting__Robert_Joe_Wagner_and_James_Spyridon_Vlassakis.txt
# [220/274] Scraping: Mailoni Brothers (Table 6)
# Saved Mailoni_Brothers.txt
# [221/274] Scraping: Leonard Lake, and, Charles Ng (Table 6)
# Saved Leonard_Lake__and__Charles_Ng.txt
# [222/274] Scraping: Bloody Benders (Table 6)
# Saved Bloody_Benders.txt
# [223/274] Scraping: Shen Changyin and Shen Changping (Table 6)
# Saved Shen_Changyin_and_Shen_Changping.txt
# [224/274] Scraping: Polatbay Berdaliyev, and Abduseit Ormanov (Table 6)
# Saved Polatbay_Berdaliyev__and_Abduseit_Ormanov.txt
# [225/274] Scraping: Wolfgang Abel and Marco Furlan (Table 6)
# Saved Wolfgang_Abel_and_Marco_Furlan.txt
# [226/274] Scraping: Juan Carlos Hernández and Patricia Martínez (Table 6)
# Saved Juan_Carlos_Hernández_and_Patricia_Martínez.txt
# [227/274] Scraping: Hillside Stranglers (Table 6)
# Saved Hillside_Stranglers.txt
# [228/274] Scraping: Joshi-Abhyankar serial murderers (Table 6)
# Saved Joshi_Abhyankar_serial_murderers.txt
# [229/274] Scraping: Gerald and Charlene Gallego (Table 6)
# Saved Gerald_and_Charlene_Gallego.txt
# [230/274] Scraping: Viña del Mar psychopaths (Table 6)
# Saved Viña_del_Mar_psychopaths.txt
# [231/274] Scraping: Wang Zongfang and Wang Zongwei (Table 6)
# Saved Wang_Zongfang_and_Wang_Zongwei.txt
# [232/274] Scraping: Yevgeny Nagorny, and Sergei Stavitsky (Table 6)
# Saved Yevgeny_Nagorny__and_Sergei_Stavitsky.txt
# [233/274] Scraping: National Socialist Underground (Table 6)
# Saved National_Socialist_Underground.txt
# [234/274] Scraping: The Manson Family cult killings (Table 6)
# Saved The_Manson_Family_cult_killings.txt
# [235/274] Scraping: Bruno Lüdke (Table 7)
# Saved Bruno_Lüdke.txt
# [236/274] Scraping: "Highway of Tears" Killer (Table 7)
# Saved _Highway_of_Tears__Killer.txt
# [237/274] Scraping: Orlando Sabino (Table 7)
# Saved Orlando_Sabino.txt
# [238/274] Scraping: Charles Quansah (Table 7)
# Saved Charles_Quansah.txt
# [239/274] Scraping: Redhead murders (Table 7)
# Saved Redhead_murders.txt
# [240/274] Scraping: Jeff Davis 8 (Table 7)
# Saved Jeff_Davis_8.txt
# [241/274] Scraping: Pedro Rosa da Conceição (Table 7)
# Saved Pedro_Rosa_da_Conceição.txt
# [242/274] Scraping: Earl Bramblett (Table 7)
# Saved Earl_Bramblett.txt
# [243/274] Scraping: Henry Lee Lucas (Table 7)
# Saved Henry_Lee_Lucas.txt
# [244/274] Scraping: "Bowraville Murders" Killer (Table 7)
# Saved _Bowraville_Murders__Killer.txt
# [245/274] Scraping: Billy Gohl (Table 7)
# Saved Billy_Gohl.txt
# [246/274] Scraping: Christopher Halliwell (Table 7)
# Saved Christopher_Halliwell.txt
# [247/274] Scraping: Larry Hall (Table 7)
# Saved Larry_Hall.txt
# [248/274] Scraping: Alejandro Máynez (Table 7)
# Saved Alejandro_Máynez.txt
# [249/274] Scraping: Kieran Patrick Kelly (Table 7)
# Saved Kieran_Patrick_Kelly.txt
# [250/274] Scraping: Wayne Williams (Table 7)
# Saved Wayne_Williams.txt
# [251/274] Scraping: Gerard John Schaefer (Table 7)
# Saved Gerard_John_Schaefer.txt
# [252/274] Scraping: Billy Chemirmir (Table 7)
# Saved Billy_Chemirmir.txt
# [253/274] Scraping: Allan Grimson (Table 7)
# Saved Allan_Grimson.txt
# [254/274] Scraping: Billy Edwin Reid (Table 7)
# Saved Billy_Edwin_Reid.txt
# [255/274] Scraping: Joe Ball (Table 7)
# Saved Joe_Ball.txt
# [256/274] Scraping: Alun Kyte (Table 7)
# Saved Alun_Kyte.txt
# [257/274] Scraping: Larry Gene Bell (Table 7)
# Saved Larry_Gene_Bell.txt
# [258/274] Scraping: Michael Stone (Table 7)
# Saved Michael_Stone.txt
# [259/274] Scraping: David Smith (Table 7)
# Saved David_Smith.txt
# [260/274] Scraping: James Otto Earhart (Table 7)
# Saved James_Otto_Earhart.txt
# [261/274] Scraping: Jeffrey Willis (Table 7)
# Saved Jeffrey_Willis.txt
# [262/274] Scraping: Ángel Nieves Díaz (Table 7)
# Saved Ángel_Nieves_Díaz.txt
# [263/274] Scraping: Pam Hupp (Table 7)
# Saved Pam_Hupp.txt
# [264/274] Scraping: Johann Otto Hoch (Table 7)
# Saved Johann_Otto_Hoch.txt
# [265/274] Scraping: Clementine Barnabet (Table 7)
# Saved Clementine_Barnabet.txt
# [266/274] Scraping: Jessie McTavish (Table 7)
# Saved Jessie_McTavish.txt
# [267/274] Scraping: Bobby Jack Fowler (Table 7)
# Saved Bobby_Jack_Fowler.txt
# [268/274] Scraping: Abdul Latif Sharif (Table 7)
# Saved Abdul_Latif_Sharif.txt
# [269/274] Scraping: Leszek Pękalski (Table 7)
# Saved Leszek_Pękalski.txt
# [270/274] Scraping: Daisuke Mori (Table 7)
# Saved Daisuke_Mori.txt
# [271/274] Scraping: Thomas Henry McMonigle (Table 7)
# Saved Thomas_Henry_McMonigle.txt
# [272/274] Scraping: Bevan Spencer von Einem (Table 7)
# Saved Bevan_Spencer_von_Einem.txt
# [273/274] Scraping: Paul Bateson (Table 7)
# Saved Paul_Bateson.txt
# [274/274] Scraping: Derek Percy (Table 7)
# Saved Derek_Percy.txt
#
# ================================================================================
# SCRAPING COMPLETED!
# ================================================================================
# Files saved in 'serial_killers_texts' folder
# Total files: 274

# %%
# ------- Preprocessing steps -----------
folder = "serial_killers_texts"
data = []

for filename in os.listdir(folder):
    if filename.endswith(".txt"):
        name = os.path.splitext(filename)[0]  # remove .txt extension
        path = os.path.join(folder, filename)

        with open(path, "r", encoding="utf-8") as f:
            text = f.read()

        # Only include non-empty text
        if text.strip():
            # Parse the structured data
            lines = text.split('\n')

            # Extract table data (before the separator)
            table_data = {}
            wiki_content = []
            in_wiki_section = False

            for line in lines:
                if not in_wiki_section:
                    # Parse key-value pairs from table data
                    if ':' in line:
                        parts = line.split(':', 1)
                        if len(parts) == 2:
                            key = parts[0].strip()
                            value = parts[1].strip()
                            table_data[key] = value
                else:
                    wiki_content.append(line)

            # Create clean text without table number and separators
            clean_text_parts = []

            # Add table data (excluding Table number)
            for key, value in table_data.items():
                if key != "Table" and value:  # Exclude Table field
                    clean_text_parts.append(f"{key}: {value}")

            # Add wiki content (already extracted above)
            wiki_text = '\n'.join(wiki_content).strip()
            if wiki_text:
                clean_text_parts.append("\n" + wiki_text)

            clean_full_text = '\n'.join(clean_text_parts)


            # Combine into a single record
            record = {
                "name": name,
                "full_name": table_data.get("Name", name),
                "country": table_data.get("Country", ""),
                "years_active": table_data.get("Years active", ""),
                "proven_victims": table_data.get("Proven victims", ""),
                "possible_victims": table_data.get("Possible victims", ""),
                "notes": table_data.get("Notes", ""),
                "wiki_content": '\n'.join(wiki_content).strip(),
                "text": text
            }

            data.append(record)

# Create DataFrame
df = pd.DataFrame(data)

print("="*80)
print("DATAFRAME OVERVIEW")
print("="*80)
print(f"\nShape: {df.shape}")
print(f"Columns: {list(df.columns)}")

# Display first few rows (limited view)
print("\n" + "="*80)
print("FIRST 3 ENTRIES (Sample)")
print("="*80)
for idx, row in df.head(3).iterrows():
    print(f"\n{idx+1}. {row['full_name']}")
    print(f"   Country: {row['country']}")
    print(f"   Years Active: {row['years_active']}")
    print(f"   Proven Victims: {row['proven_victims']}")
    print(f"   Possible Victims: {row['possible_victims']}")
    print(f"   Notes (first 100 chars): {row['notes'][:100] if len(row['notes']) > 100 else row['notes']}...")

# Data quality checks
print("\n" + "="*80)
print("DATA QUALITY CHECKS")
print("="*80)

# Count rows where 'wiki_content' is empty or only whitespace
empty_wiki_count = df['wiki_content'].str.strip().eq('').sum()
print(f"Empty wiki content entries: {empty_wiki_count}")

# Count rows where 'notes' is empty
empty_notes_count = df['notes'].str.strip().eq('').sum()
print(f"Empty notes entries: {empty_notes_count}")

# Check for missing values
print("\nMissing values per column:")
print(df.isnull().sum())

# Check for duplicates
print(f"\nDuplicate rows: {df.duplicated().sum()}")

# Save to CSV for easy inspection
df.to_csv("serial_killers_data.csv", index=False, encoding="utf-8")
print("\nData saved to 'serial_killers_data.csv'")
# Out:
# ================================================================================
# DATAFRAME OVERVIEW
# ================================================================================
#
# Shape: (274, 9)
# Columns: ['name', 'full_name', 'country', 'years_active', 'proven_victims', 'possible_victims', 'notes', 'wiki_content', 'text']
#
# ================================================================================
# FIRST 3 ENTRIES (Sample)
# ================================================================================
#
# 1. Niels Högel
#    Country: Germany
#    Years Active: 1999–2005
#    Proven Victims: 85+
#    Possible Victims: 300, [, 415, ]
#    Notes (first 100 chars): Nurse who was sentenced to life imprisonment for the murder of more than 85 people., [, 416, ], [, 4...
#
# 2. Viktor Sayenko and Igor Suprunyuk
#    Country: Ukraine
#    Years Active: 2007
#    Proven Victims: 21
#    Possible Victims:
#    Notes (first 100 chars): "The Dnepropetrovsk Maniacs". A pair of 19-year-olds who, over the course of less than a month, atta...
#
# 3. Kimberly Clark Saenz
#    Country: United States
#    Years Active: 2008
#    Proven Victims: 5
#    Possible Victims:
#    Notes (first 100 chars): Killed five patients by using syringes to inject bleach into their dialysis lines....
#
# ================================================================================
# DATA QUALITY CHECKS
# ================================================================================
# Empty wiki content entries: 274
# Empty notes entries: 0
#
# Missing values per column:
# name                0
# full_name           0
# country             0
# years_active        0
# proven_victims      0
# possible_victims    0
# notes               0
# wiki_content        0
# text                0
# dtype: int64
#
# Duplicate rows: 0
#
# Data saved to 'serial_killers_data.csv'

# %%
# See all the unique countries that exist on the dataset
unique_countries = df['country'].unique()

print(unique_countries)
# Out:
# ['Germany' 'Ukraine' 'United States' 'Colombia' 'Canada' 'Japan' 'Italy'
#  'Colombia, Ecuador, Brazil' 'Belgium, France' 'France' 'Soviet Union'
#  'United States, Canada' 'China' 'United Kingdom'
#  'United States, Austria, , France, , United Kingdom' 'Australia'
#  'South Africa' 'Iraq' 'Zambia' 'Afghanistan' 'Thailand' 'Hungary' 'Iran'
#  'Mexico' 'Soviet Union, Kazakhstan' 'Switzerland' 'Ecuador'
#  'Ottoman Empire, Iraq, Iran' 'France, Germany, , Switzerland'
#  'South Korea' 'Indonesia' 'Netherlands' 'Colombia, Ecuador, , Venezuela'
#  'Norway' 'Soviet Union, Russia' 'Pakistan' 'Sweden' 'Austria' 'Russia'
#  'Swaziland' 'Guatemala'
#  'United Kingdom, Ireland, , West Germany, , Netherlands, , France'
#  'Brazil' 'Ghana' 'India' 'Rwanda' 'Egypt' 'Greece'
#  'Soviet Union, Ukraine' 'Poland'
#  'Kingdom of Romania, Yugoslavia, Hungary' 'Venezuela' 'Finland' 'Morocco'
#  'Latvia' 'Austria-Hungary' 'Costa Rica' 'Belgian Congo, Tanganyika'
#  'Spain' 'West Germany' 'Soviet Union, Russia, Tajikistan'
#  'Italy, West Germany, Netherlands' 'Chile' 'Uzbekistan, Kazakhstan'
#  'Tunisia' 'Imperial State of Iran' 'United States, Mexico' 'Romania'
#  'Argentina' 'United States, Zimbabwe' 'Czech Republic'
#  'Kingdom of Yugoslavia' 'United States, Puerto Rico'
#  'Colombia, Peru, Ecuador' 'Czechoslovakia']

# %% [markdown]
# ###Preprocessing

# %% [markdown]
# ### The Preprocessing steps we will use are:
# #### Lower Casing
# #### Removing Non-Alphabets
# #### Removing Punctuation
# #### Removing Stopwords
# #### Removing Short Words
# #### Lemmatization

# %%
# Minima Cleaning(For Embeddings & LLM)
def minimal_clean(text):
    """
    Only fixes encoding/spacing. Keeps grammar/punctuation for the LLM.
    """
    text = str(text).replace('\xa0', ' ')
    text = re.sub(r'\s+', ' ', text).strip()
    return text

# Apply this to the main 'text' column.
# This ensures 'df["text"]' remains readable English.
df['text'] = df['text'].apply(minimal_clean)
df['name'] = df['name'].apply(minimal_clean)

# %%
def clean_text_for_search(text):
    text = str(text).lower()

    # 1. Replace all non-alphanumeric, non-space characters with a single SPACE.
    # This separates numbers from dashes, commas, or periods (e.g., '25/05/2024' -> '25 05 2024').
    text = re.sub(r'[^a-z0-9 ]', ' ', text)

    # 2. Normalize whitespace and strip.
    text = re.sub(r'\s+', ' ', text).strip()

    return text

# %%
# Load spaCy model for:
# 1. Stopword removal
# 2. Lemmatization
# 3. Tokenization
nlp = spacy.load("en_core_web_sm")

# %%
# ---- Base stopwords ----
base_stopwords = set(nlp.Defaults.stop_words)

# ---- Words to keep ----
preserve = {
    # Negation
    'not', 'no', "n't", 'never', 'without',
    # Quantity/Extent
    'only', 'less', 'more', 'most', 'almost', 'fully', 'partially',
    # Chronology/Sequence
    'first', 'last', 'before', 'after', 'once', 'while',
    # Comparison/Condition/Relationship
    'against', 'though', 'although', 'unless', 'except', 'whether', 'between', 'with'
}

# Remove preserved words from stopword list
custom_stopwords = base_stopwords - preserve



# ---- Stopword removal using nlp(text) ----
def remove_stopwords(text):
    doc = nlp(text)

    filtered = [
        token.text
        for token in doc
        if token.text.lower() not in custom_stopwords
    ]

    return " ".join(filtered)

# %%
def remove_short_words_keep_numbers(text, min_len=3):
    words = text.split()
    filtered = []
    for w in words:
        if w.isdigit():
            # keep any number, regardless of length
            filtered.append(w)
        elif len(w) >= min_len:
            filtered.append(w)
    return " ".join(filtered)

# %%
# Function to remove and replace the (+) sign on specific columns
def parse_int(x):
    if pd.isna(x):
        return None
    x = str(x).strip().replace("+", "")
    match = re.search(r"\d+", x)
    return int(match.group()) if match else None

df["proven_victims"] = df["proven_victims"].apply(parse_int)
df["possible_victims"] = df["possible_victims"].apply(parse_int)

# %% [markdown]
# #Chunk the text

# %%
def chunk_by_words(text, chunk_size=250, overlap=40):
    words = str(text).split()
    if not words:
        return []
    overlap = max(0, min(overlap, max(0, chunk_size - 1)))  # guard
    chunks = []
    start, n = 0, len(words)
    while start < n:
        end = min(n, start + chunk_size)
        chunks.append(" ".join(words[start:end]))
        if end == n:
            break
        start = end - overlap
    return chunks

# Chunk the natural text (df['text'])
df["chunks"] = df["text"].apply(lambda t: chunk_by_words(t, chunk_size=250, overlap=40))

# Show results
total_chunks = sum(len(ch) for ch in df["chunks"])
print(f"Created {total_chunks} total chunks")
# Out:
# Created 2254 total chunks

# %%
chunked_rows = []
for doc_idx, row in df.iterrows():
    for chunk_idx, chunk in enumerate(row["chunks"]):
        # 1. Clean
        sparse_text = clean_text_for_search(chunk)
        # 2. Stopwords
        sparse_text = remove_stopwords(sparse_text)
        # 3. Short words
        sparse_text = remove_short_words_keep_numbers(sparse_text, min_len=3)
        # 4. Lemmatization
        sparse_tokens = [token.lemma_ for token in nlp(sparse_text)]
        sparse_text_final = " ".join(sparse_tokens)

        chunked_rows.append({
            "doc_index": doc_idx,
            "name": row["name"],
            "chunk_index": chunk_idx,

            # This is Natural English (for Embeddings/LLM)
            "text": chunk,

            # This is for BM25/TF-IDF
            "text_bm25": sparse_text_final,

            "proven_victims": row["proven_victims"],
            "possible_victims": row["possible_victims"],
            "country": row["country"],
            "years_active": row["years_active"],
        })

# Create DataFrame and sort it
chunked_df = pd.DataFrame(chunked_rows)
chunked_df.to_csv('serial_killers_chunked.csv', index=False)
print(f"Saved {len(chunked_df)} chunks to CSV")
# Out:
# Saved 2254 chunks to CSV

# %%
# Inspect the columns
print(f"Columns: {list(chunked_df.columns)}")
# Out:
# Columns: ['doc_index', 'name', 'chunk_index', 'text', 'text_bm25', 'proven_victims', 'possible_victims', 'country', 'years_active']

# %%
# Optionally save the file to local environment
files.download("serial_killers_chunked.csv")

# %% [markdown]
# ##BM25+ Ranking Algorithm - Keyword Matching

# %% [markdown]
# ## Prepare tokenized corpus for BM25+

# %%
# Prepare for lexical models BM25+ and TF-IDF
chunked_df["text_bm25"] = chunked_df["text_bm25"].astype(str)
chunked_df["tokens"] = chunked_df["text_bm25"].str.split()
corpus_tokens = chunked_df["tokens"].tolist()

# Build BM25+ model
bm25 = BM25Plus(corpus_tokens)
print(f"BM25+ corpus size: {len(corpus_tokens)} chunks")
# Out:
# BM25+ corpus size: 2254 chunks

# %% [markdown]
# ## BM25+ search function (keyword matching)

# %%
def clean_query_for_bm25(query: str) -> list:
# Use functions on the query too
    q = clean_text_for_search(query)
    q = remove_stopwords(q)
    q = remove_short_words_keep_numbers(q, min_len=3)
    # Lemmatize query
    q_tokens = [token.lemma_ for token in nlp(q)]
    return q_tokens # returns list directly

def search_bm25(query: str, top_k: int = 5):
  q_tokens = clean_query_for_bm25(query)
  if not q_tokens:
    print("Empty query.")
    return pd.DataFrame()

  scores = np.array(bm25.get_scores(q_tokens))
  top_idx = np.argsort(scores)[::-1][:top_k]
  results = chunked_df.iloc[top_idx].copy()
  results["bm25_score"] = scores[top_idx]
  # Snippet comes from natural text
  results["snippet"] = results["text"].str[:250] + "..."
  return results.sort_values("bm25_score", ascending=False).reset_index(drop=True)

# %% [markdown]
# ##TF-IDF Vector Space Search - Semantic

# %%
# TF-IDF on lemma chunks
# TF-IDF on the sparse column (text_bm25)
tfidf_vectorizer = TfidfVectorizer(ngram_range=(1, 2), max_df=0.9, min_df=1)
tfidf_matrix = tfidf_vectorizer.fit_transform(chunked_df["text_bm25"])
print("TF-IDF matrix shape:", tfidf_matrix.shape)

def search_tfidf(query: str, top_k: int = 5):
    # Clean query same as corpus
    q = clean_text_for_search(query)
    q = remove_stopwords(q)
    q = remove_short_words_keep_numbers(q, min_len=3)
    q = " ".join([token.lemma_ for token in nlp(q)])

    if not q:
        print("Empty query.")
        return pd.DataFrame()

    sims = cosine_similarity(tfidf_vectorizer.transform([q]), tfidf_matrix)[0]
    top_idx = np.argsort(sims)[::-1][:top_k]
    results = chunked_df.iloc[top_idx].copy()
    results["tfidf_score"] = sims[top_idx]
    # Snippet comes from natural text
    results["snippet"] = results["text"].str[:250] + "..."
    return results.sort_values("tfidf_score", ascending=False).reset_index(drop=True)
# Out:
# TF-IDF matrix shape: (2254, 200823)

# %% [markdown]
# ## Embeddings with hugging face personal token for model all-mpnet-base-v2.

# %%
# Ask the user for their Hugging Face token to access gated models
os.environ['HF_TOKEN'] = getpass.getpass("Enter the value for HF_TOKEN: ")
# Out:
# Enter the value for HF_TOKEN: ··········

# %%
# Set the cache directory for Hugging Face models and tokenizers
os.environ["HF_HOME"] = "/content/my_huggingface_cache"

# %%
# Check for available GPUs and set the device accordingly
if torch.cuda.device_count()>0:
    my_device = "cuda"
    print(f"You have {torch.cuda.device_count()} GPUs available.")
else:
    my_device = "cpu"
    print("You have no GPUs available. Running on CPU.")
# Out:
# You have 1 GPUs available.

# %%
# Load a compact sentence embedding model with authorization and caching
embeddings_model = SentenceTransformer('sentence-transformers/all-mpnet-base-v2', token=os.environ["HF_TOKEN"],
                                       cache_folder=os.environ["HF_HOME"], device=my_device)
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
# Use natural text (df['text']) for embeddings
my_sentences = chunked_df["text"].tolist()

# %%
# Encode document corpus with batches
my_embeddings = embeddings_model.encode(my_sentences, batch_size=32, show_progress_bar=True, convert_to_numpy=True)
print("My embeddings shape:", my_embeddings.shape)
# Out:
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# My embeddings shape: (2254, 768)

# %% [markdown]
# #Qdrant Storage of the Embeddings

# %%
# Connect to personal 
Cloud cluster

QDRANT_URL = "...."   # <---- put your QDRANT URL here !!!
API_KEY = "...."   # <---- Put your API key here !!!

client = QdrantClient(
    url=QDRANT_URL,
    api_key=API_KEY
)


# Create a collection in Qdrant

client.recreate_collection(
    collection_name="serial_killers",
    vectors_config=VectorParams(
        size=my_embeddings.shape[1],  # embedding dimension (768 for all-mpnet-base-v2)
        distance=Distance.COSINE
    )
)



# numeric index for proven_victims
client.create_payload_index(
    collection_name="serial_killers",
    field_name="proven_victims",
    field_schema=PayloadSchemaType.INTEGER
)

# numeric index for possible_victims
client.create_payload_index(
    collection_name="serial_killers",
    field_name="possible_victims",
    field_schema=PayloadSchemaType.INTEGER
)

# keyword index for country
client.create_payload_index(
    collection_name="serial_killers",
    field_name="country",
    field_schema=PayloadSchemaType.KEYWORD
)

# keyword index for name
client.create_payload_index(
    collection_name="serial_killers",
    field_name="name",
    field_schema=PayloadSchemaType.KEYWORD
)


# Prepare metadata payloads

payloads = []
for i, row in chunked_df.iterrows():
    payloads.append({
        "text": row["text"],
        "name": row["name"],
        "full_name": row.get("full_name"),
        "proven_victims": int(row["proven_victims"]) if pd.notna(row["proven_victims"]) else None,
        "possible_victims": int(row["possible_victims"]) if pd.notna(row["possible_victims"]) else None,
        "country": row.get("country"),
        "years_active": row.get("years_active"),
    })


# Create unique IDs for each chunk
ids = list(range(len(my_sentences)))


# Upload the embeddings at batches

batch_size = 500
for i in range(0, len(my_sentences), batch_size):
    batch_vectors = my_embeddings[i:i+batch_size]
    batch_payloads = payloads[i:i+batch_size]
    batch_ids = ids[i:i+batch_size]

    client.upsert(
        collection_name="serial_killers",
        points=Batch(
            ids=batch_ids,
            vectors=batch_vectors,
            payloads=batch_payloads
        )
    )

print("All embeddings successfully uploaded to Qdrant Cloud")
# Out:
# /tmp/ipython-input-2853667795.py:14: DeprecationWarning: `recreate_collection` method is deprecated and will be removed in the future. Use `collection_exists` to check collection existence and `create_collection` instead.
#   client.recreate_collection(
# All embeddings successfully uploaded to Qdrant Cloud

# %%
def preprocess_query_for_embedding(query: str):
    # 1. Lowercase
    q = query.lower()

    # 2. Remove special characters (optional, but good for noise reduction)
    # This keeps only letters, numbers, and basic punctuation
    # removes commas so "1,000" becomes "1000")
    q = re.sub(r'[^a-z0-9\s\?\.]', '', q).replace(',', '')

    # 3. Strip extra whitespace
    q = " ".join(q.split())

    return q

# %%
def parse_numeric_filters(query: str):
    """
    Detects strict numeric conditions: Greater Than, Less Than, Equal.
    """
    q = query.lower().replace(',', '')

    # 1. Determine Target Field
    target_field = "proven_victims"
    possible_keywords = ["possible", "suspected", "estimated", "alleged", "potential"]
    if any(word in q for word in possible_keywords):
        target_field = "possible_victims"

    # 2. Strict Patterns
    patterns = [
        # GREATER THAN (>)
        (r"more than (\d+)", "gt"),
        (r"over (\d+)", "gt"),
        (r"above (\d+)", "gt"),

        # LESS THAN (<)
        (r"less than (\d+)", "lt"),
        (r"under (\d+)", "lt"),
        (r"below (\d+)", "lt"),

        # EQUAL (=)
        (r"exactly (\d+)", "eq"),
        (r"(\d+)\s+victims", "eq"),
        (r"(\d+)\s+possible", "eq"),
        # Catch just a number if it implies exact count
        # e.g. "killers with 20 victims" -> eq 20
        (r"with (\d+)$", "eq"),
    ]

    for pattern, operator in patterns:
        match = re.search(pattern, q)
        if match:
            value = int(match.group(1))
            return (target_field, operator, value)

    return None

# %%
# Only single, valid country names
COUNTRIES = [
    'Afghanistan', 'Argentina', 'Australia', 'Austria', 'Belgium', 'Brazil',
    'Canada', 'Chile', 'China', 'Colombia', 'Czech Republic', 'Czechoslovakia',
    'Ecuador', 'France', 'Germany', 'Ghana', 'Greece', 'Guatemala', 'Hungary',
    'India', 'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Italy', 'Japan',
    'Kazakhstan', 'Latvia', 'Mexico', 'Morocco', 'Netherlands', 'Norway',
    'Pakistan', 'Peru', 'Poland', 'Puerto Rico', 'Romania', 'Russia', 'Rwanda',
    'South Africa', 'South Korea', 'Soviet Union', 'Spain', 'Swaziland',
    'Sweden', 'Switzerland', 'Tajikistan', 'Thailand', 'Tunisia', 'Ukraine',
    'United Kingdom', 'United States', 'Uzbekistan', 'Venezuela', 'West Germany',
    'Yugoslavia', 'Zambia'
]

# Sort by length (descending) to match "South Africa" before "Africa" or "United States" before "States"
COUNTRIES.sort(key=len, reverse=True)

def extract_country(query: str):
    q = query.lower()
    for c in COUNTRIES:
        if c.lower() in q:
            return c
    return None

# %%
def build_qdrant_filter(query:str):
    """
    Returns a Qdrant Filter object based on the detected numeric/country filters.
    """

    numeric = parse_numeric_filters(query)
    country = extract_country(query)

    must_clauses = []

    # Country filter
    if country:
        must_clauses.append(
            FieldCondition(
                key="country",
                match=MatchValue(value=country)
            )
        )

    # Numeric victims filter
    if numeric:
        # Unpack the 3 values
        field_name, op, value = numeric

        if op == "gt":
            rng = Range(gt=value)
        elif op == "lt":
            rng = Range(lt=value)
        else:
            rng = Range(gte=value, lte=value)

        # Apply filter to the specific field detected (proven OR possible)
        must_clauses.append(
            FieldCondition(
                key=field_name,
                range=rng
            )
        )

    if not must_clauses:
        return None  # no filtering needed

    return Filter(must=must_clauses)

# %% [markdown]
# ## Comparison BM25 vs TF-IDF vs Embeddings

# %%
# Sample Query
query_sample = "How did Samuel Little killed his victims?"

# %%
# Preprocess the sample query
query_sample = preprocess_query_for_embedding(query_sample)

# %%
# Embedding the preprocessed sample query
my_question_embedding = embeddings_model.encode([query_sample])[0].tolist()

# %%
def hybrid_qdrant_search(client, collection_name, query: str, query_embedding, top_k=40):
    """
    Performs semantic + structured search in Qdrant.
    Returns: raw Qdrant response object (to access .points) and formatted results
    """
    q_filter = build_qdrant_filter(query)

    # Get raw Qdrant response
    raw_results = client.query_points(
        collection_name=collection_name,
        query=query_embedding,
        limit=top_k,
        with_payload=True,
        query_filter=q_filter
    )

    # Also create formatted results
    formatted_results = []
    for point in raw_results.points:
      # Handle Country List for Display
      country_val = point.payload.get("country")

      # If it's a list (e.g., ['USA', 'Canada']), join it into a string
      if isinstance(country_val, list):
        country_display = ", ".join(country_val)
      else:
        # Fallback if it's None or already a string
        country_display = str(country_val) if country_val else "Unknown"

      formatted_results.append({
          "score": point.score,
          "name": point.payload.get("name"),
          "country": point.payload.get("country"),
          "proven_victims": point.payload.get("proven_victims"),
          "possible_victims": point.payload.get("possible_victims"),
          "text": point.payload.get("text")[:300] + "..." if point.payload.get("text") else "",
      })

    return raw_results, formatted_results

# Results
raw_embeddings_results, formatted_embeddings_results = hybrid_qdrant_search(
    client,
    "serial_killers",
    query_sample,
    my_question_embedding,
    top_k=40
)

# -------------------------------
# Display results - Comparison
print(f"Query: {query_sample}")
print("="*50)

print("\n--- Embeddings Results ---")
# Use the formatted results here so we see the clean country names
for i, res in enumerate(formatted_embeddings_results):
    print(f"[{i+1}] {res['name']} ({res['country']})")
    print(f"    Score: {res['score']:.3f}")
    print(f"    Victims: Proven {res['proven_victims']} / Possible {res['possible_victims']}")
    print(f"    Snippet: {res['text'][:100]}...")
    print()

# BM25 and TF-IDF Score Results
bm25_results = search_bm25(query_sample, top_k=40)
tfidf_results = search_tfidf(query_sample, top_k=40)

print("\n--- BM25 Results ---")
for i, row in bm25_results.iterrows():
    scaled = row['bm25_score'] / 100
    print(f"[{i+1}] {row['name']}  score={scaled:.3f}")
    print(row["snippet"])
    print()

print("\n--- TF-IDF Results ---")
for i, row in tfidf_results.iterrows():
    print(f"[{i+1}] {row['name']}  score={row['tfidf_score']:.3f}")
    print(row["snippet"])
    print()
# Out:
# Query: how did samuel little killed his victims?
# ==================================================
#
# --- Embeddings Results ---
# [1] Samuel_Little (United States)
#     Score: 0.611
#     Victims: Proven 60 / Possible 93
#     Snippet: Name: Samuel Little Country: United States Years active: 1970–2005 Proven victims: 60 Possible victi...
#
# [2] Larry_Eyler (United States)
#     Score: 0.518
#     Victims: Proven 19 / Possible 23
#     Snippet: murder, Little had suggested the two "do a scene", which he had understood to mean commit a murder f...
#
# [3] Larry_Eyler (United States)
#     Score: 0.510
#     Victims: Proven 19 / Possible 23
#     Snippet: several victims were subjected to varying degrees of sadomasochism before being stabbed and/or slash...
#
# [4] Larry_Eyler (United States)
#     Score: 0.492
#     Victims: Proven 19 / Possible 23
#     Snippet: been too fast for his liking. Upon cross-examination, one of Little's defense attorneys, Dennis Zahn...
#
# [5] Larry_Eyler (United States)
#     Score: 0.486
#     Victims: Proven 19 / Possible 23
#     Snippet: victims were discovered alongside an oak tree close to an abandoned farmhouse in Lake Village, India...
#
# [6] Larry_Eyler (United States)
#     Score: 0.471
#     Victims: Proven 19 / Possible 23
#     Snippet: a penchant for sadomasochism, and their sexual activity frequently involved Eyler binding his partne...
#
# [7] Samuel_Little (United States)
#     Score: 0.468
#     Victims: Proven 60 / Possible 93
#     Snippet: and leave fewer persons to search for them. Despite the broad scope of his offending, Little was cha...
#
# [8] Larry_Eyler (United States)
#     Score: 0.461
#     Victims: Proven 19 / Possible 23
#     Snippet: before stating: "This is the [most extensively mutilated body] I've seen without the body being cut ...
#
# [9] Larry_Eyler (United States)
#     Score: 0.457
#     Victims: Proven 19 / Possible 23
#     Snippet: his vehicle and also agreed to allow investigators to take his mug shot, copies of his fingerprints,...
#
# [10] Samuel_Little (United States)
#     Score: 0.457
#     Victims: Proven 60 / Possible 93
#     Snippet: Upon his release in February 1987, he immediately moved to Los Angeles and committed at least 10 add...
#
# [11] Fritz_Haarmann (Germany)
#     Score: 0.456
#     Victims: Proven 24 / Possible 27
#     Snippet: the abdominal cavity to soak the collecting blood. He would then make three cuts between the victim'...
#
# [12] John_Justin_Bunting__Robert_Joe_Wagner_and_James_Spyridon_Vlassakis (Australia)
#     Score: 0.455
#     Victims: Proven 12 / Possible None
#     Snippet: Some were befriended for a short time and pulled into the group as easy targets for Bunting. Kevin H...
#
# [13] Clementine_Barnabet (United States)
#     Score: 0.455
#     Victims: Proven 1 / Possible 35
#     Snippet: surgical operation was believed to have cured her (not a lobotomy, which was unknown in the United S...
#
# [14] Samuel_Little (United States)
#     Score: 0.452
#     Victims: Proven 60 / Possible 93
#     Snippet: of 2018, Little confessed to the 1982 murder of 55-year-old Dorothy Richards and the 1996 murder of ...
#
# [15] Belle_Gunness (United States)
#     Score: 0.452
#     Victims: Proven 14 / Possible 40
#     Snippet: When Lamphere was arrested, he was wearing John Moe's overcoat and Henry Gurholt's watch. Edward Bec...
#
# [16] Larry_Eyler (United States)
#     Score: 0.451
#     Victims: Proven 19 / Possible 23
#     Snippet: Robert Little in 1984. Following Eyler's arrest and conviction for the murder of Daniel Bridges, Lak...
#
# [17] Larry_Eyler (United States)
#     Score: 0.450
#     Victims: Proven 19 / Possible 23
#     Snippet: in Eyler frequently bringing young men to Little's home to engage in sex with the two. On August 3, ...
#
# [18] Larry_Eyler (United States)
#     Score: 0.448
#     Victims: Proven 19 / Possible 23
#     Snippet: October 1, investigators from CIMAIT obtained a search warrant authorizing their search of the Terre...
#
# [19] Larry_Eyler (United States)
#     Score: 0.443
#     Victims: Proven 19 / Possible 23
#     Snippet: been murdered with the assistance of Robert Little (to whom Zellner referred in this press conferenc...
#
# [20] William_Unek (Belgian Congo, Tanganyika)
#     Score: 0.441
#     Victims: Proven 58 / Possible 58
#     Snippet: axe. After attacking Opiyo, William had broken into the police armoury, using an axe to break the do...
#
# [21] Michael_Swango (United States, Zimbabwe)
#     Score: 0.441
#     Victims: Proven 4 / Possible 35
#     Snippet: sentencing hearing, Swango admitted to causing three murders, lying about his role in causing a four...
#
# [22] Robert_Black (United Kingdom, Ireland, , West Germany, , Netherlands, , France)
#     Score: 0.441
#     Victims: Proven 4 / Possible 18
#     Snippet: counsel had fundamentally objected to. Black also contended that the final instructions delivered to...
#
# [23] Cape_Town_Prostitute_Killer (South Africa)
#     Score: 0.439
#     Victims: Proven 19 / Possible 20
#     Snippet: he would order his victim to take her clothes off and then hit her in the face. Every victim had inj...
#
# [24] Clementine_Barnabet (United States)
#     Score: 0.439
#     Victims: Proven 1 / Possible 35
#     Snippet: of the victims. Every victim was slashed or bludgeoned with an ax, which was the cause of death for ...
#
# [25] Andrei_Chikatilo (Soviet Union)
#     Score: 0.438
#     Victims: Proven 53 / Possible 56
#     Snippet: September 1982, he killed a further five victims between the ages of 9 and 18. He established a patt...
#
# [26] Cape_Town_Prostitute_Killer (South Africa)
#     Score: 0.438
#     Victims: Proven 19 / Possible 20
#     Snippet: prostitutes. He also drove a blue and white bakkie, which matched the description of a vehicle that ...
#
# [27] Cleveland_Torso_Murderer (United States)
#     Score: 0.438
#     Victims: Proven 13 / Possible 40
#     Snippet: known victims were killed between 1935 and 1938. Some investigators, including lead detective Peter ...
#
# [28] Larry_Eyler (United States)
#     Score: 0.437
#     Victims: Proven 19 / Possible 23
#     Snippet: sufficient evidence existed to charge Eyler with the December 1982 murder of Steven Agan. Upon being...
#
# [29] William_Unek (Belgian Congo, Tanganyika)
#     Score: 0.437
#     Victims: Proven 58 / Possible 58
#     Snippet: stabbed another one, strangled a teenage girl, and burned two women and a child. The coroner's state...
#
# [30] Samuel_Little (United States)
#     Score: 0.436
#     Victims: Proven 60 / Possible 93
#     Snippet: 2014, Little was found guilty and was sentenced to life imprisonment without the possibility of paro...
#
# [31] Fritz_Haarmann (Germany)
#     Score: 0.433
#     Victims: Proven 24 / Possible 27
#     Snippet: to Haarmann, he never actually intended to murder any of his victims, but would be seized by an irre...
#
# [32] Larry_Eyler (United States)
#     Score: 0.433
#     Victims: Proven 19 / Possible 23
#     Snippet: on the evening of Bridges' murder. Dr. Robert Stein testified on behalf of the prosecution on July 2...
#
# [33] Larry_Eyler (United States)
#     Score: 0.432
#     Victims: Proven 19 / Possible 23
#     Snippet: Robert Little. Dobrovolskis stated this had been extremely unusual, as Little had typically returned...
#
# [34] Larry_Eyler (United States)
#     Score: 0.432
#     Victims: Proven 19 / Possible 23
#     Snippet: the defense to cast a reasonable doubt in the minds of the jury as to who had committed Bridges' mur...
#
# [35] Jerry_Brudos (United States)
#     Score: 0.432
#     Victims: Proven 4 / Possible 4
#     Snippet: the process. Hours later, Brudos severed Slawson's left foot from her body with a hacksaw; he retain...
#
# [36] William_Bonin (United States)
#     Score: 0.431
#     Victims: Proven 21 / Possible 36
#     Snippet: it surprised me that I did it. I stabbed him again and then again, and again and again until he was ...
#
# [37] Francisco_das_Chagas_Rodrigues_de_Brito (Brazil)
#     Score: 0.431
#     Victims: Proven 30 / Possible 42
#     Snippet: mechanic. The suspect was arrested on suspicion of killing Jonahtan, and 16 other boys, leading inve...
#
# [38] Larry_Eyler (United States)
#     Score: 0.430
#     Victims: Proven 19 / Possible 23
#     Snippet: ... the reason I'm here is so that the families know, he did confess to the murders of your sons. He...
#
# [39] Philipp_Tyurin (Soviet Union)
#     Score: 0.430
#     Victims: Proven 14 / Possible 29
#     Snippet: in the dead of night. The first murder he committed was in April 1945. All of the murders, as Tyurin...
#
# [40] Briley_Brothers (United States)
#     Score: 0.429
#     Victims: Proven 12 / Possible None
#     Snippet: they left, a lit match was tossed on the fuel. The two hurriedly packed their stolen loot – a televi...
#
#
# --- BM25 Results ---
# [1] Samuel_Little  score=0.276
# Name: Samuel Little Country: United States Years active: 1970–2005 Proven victims: 60 Possible victims: 93 Notes: Little was convicted of killing three women, but later investigations linked 31 other murders to him. He claimed he killed as many as 93...
#
# [2] Cape_Town_Prostitute_Killer  score=0.205
# prostitutes wrote down the registration numbers of every vehicle that picked them up. Nevertheless, seven more victims were murdered, one of whom was 39-year-old Gloria Samuels. Samuels' corpse was found heavily decomposed with a coke bottle inside o...
#
# [3] Cape_Town_Prostitute_Killer  score=0.204
# prostitutes. He also drove a blue and white bakkie, which matched the description of a vehicle that had been seen close to where Samuels' body was found. His ex-wife stated that he often disappeared for hours at a time without explaining his whereabo...
#
# [4] Cape_Town_Prostitute_Killer  score=0.197
# he would order his victim to take her clothes off and then hit her in the face. Every victim had injuries on their jaws. Afterwards, he would force the victim onto his lap and strangle her to death. He then drove to a preselected spot to dump the bod...
#
# [5] Samuel_Little  score=0.184
# and 1999. The "Jane Doe" was anywhere from 15 to 50 as the details of her age and the date of her murder are unclear. She was Black, slender, wore glasses and lived in the Over-the-Rhine neighborhood of Cincinnati with a "heavy female Hispanic". Litt...
#
# [6] Samuel_Little  score=0.181
# included his confession to a previous cold case homicide in Prince George's County, Maryland, previously one of only two homicide cases in that county with unidentified victims. In December 2018, Little was indicted for strangling Linda Sue Boards, 2...
#
# [7] Samuel_Little  score=0.178
# of 2018, Little confessed to the 1982 murder of 55-year-old Dorothy Richards and the 1996 murder of 40-year-old Daisy McGuire; both of their bodies were found in Houma, Louisiana. On November 19, 2018, Harrison County, Mississippi, sheriff Troy Peter...
#
# [8] Samuel_Little  score=0.176
# Upon his release in February 1987, he immediately moved to Los Angeles and committed at least 10 additional murders. Little was arrested on September 5, 2012, at Wayside Christian homeless shelter in Louisville, Kentucky, and extradited to California...
#
# [9] Larry_Eyler  score=0.172
# murder, Little had suggested the two "do a scene", which he had understood to mean commit a murder for sexual pleasure as Little photographed the event with a Polaroid camera.[n 11] He and Little had lured Agan—whom Eyler had vaguely known through fr...
#
# [10] Larry_Eyler  score=0.172
# October 1, investigators from CIMAIT obtained a search warrant authorizing their search of the Terre Haute home of Robert Little. This search was conducted at dawn on October 2 and revealed further circumstantial evidence, such as credit card receipt...
#
# [11] Larry_Eyler  score=0.167
# been murdered with the assistance of Robert Little (to whom Zellner referred in this press conference as "an unnamed individual still living in Indiana"). Zellner emphasized her client's insistence Little had been the individual who had actually murd...
#
# [12] Larry_Eyler  score=0.167
# been too fast for his liking. Upon cross-examination, one of Little's defense attorneys, Dennis Zahn, asserted that because Little had appeared as a witness for the prosecution at Eyler's earlier trial for the murder of Daniel Bridges, he was simply ...
#
# [13] Fernando_Hernández_Leyva  score=0.165
# childhood, so it is unclear what led to the development of his violent behavior. The actual number of victims estimated to have died at the hands of Hernández Leyva is 137, but as time passes and investigations continue, this number is increasing. Fo...
#
# [14] Samuel_Little  score=0.164
# a bar near East 105th and Euclid Avenues. He described her as a short, plump woman in her twenties with brown hair. Little confessed to killing another Cleveland woman in 1977 or 1978. The woman murdered in 1977 or 1978 was found on March 18, 1983, i...
#
# [15] Vladyslav_Volkovich_and_Volodymyr_Kondratenko  score=0.164
# so they decided to practice on the homeless. They reportedly killed at least five before risking to attack a more dangerous target. They eventually settled on attacking car owners; owning a personal vehicle was a considerable luxury and a sign of wea...
#
# [16] Samuel_Little  score=0.163
# and leave fewer persons to search for them. Despite the broad scope of his offending, Little was charged with and convicted of only eight murders in total as these cases had the strongest evidence of guilt: Little had a long-term girlfriend, Orelia D...
#
# [17] Peter_Sutcliffe  score=0.162
# The hoaxer, dubbed "Wearside Jack", sent two letters to police and the Daily Mirror in March 1978 boasting of his crimes. The letters, signed "Jack the Ripper", claimed responsibility for the November 1975 murder of 26-year-old Joan Harrison in Prest...
#
# [18] Samuel_Little  score=0.162
# problems, and other health conditions. Jillian Lauren investigated Little and interviewed him at length in prison. Lauren initially had begun writing a mystery novel, and while interviewing detective Mitzi Roberts of the Los Angeles Police Department...
#
# [19] Samuel_Little  score=0.162
# 2014, Little was found guilty and was sentenced to life imprisonment without the possibility of parole. On the day of the verdict, Little continued to insist on his innocence. Before his death, Little was serving a sentence at California State Prison...
#
# [20] Larry_Eyler  score=0.162
# before stating: "This is the [most extensively mutilated body] I've seen without the body being cut into pieces." Pless testified that many of the beating, stabbing, and slashing injuries had been inflicted after Agan was already deceased, although n...
#
# [21] Philadelphia_poison_ring  score=0.160
# he returned with Phillips and Landvoight to the Alfonsi house. They found Alfonsi to be bizarrely ill, suffering symptoms of bulging eyes, immobility, and being unable to speak. At their next meeting with Herman Petrillo, after Petrillo handed Philli...
#
# [22] Robert_Black  score=0.160
# his daughter inside, her wrists bound behind her back, her legs tied together, her mouth bound and gagged with sticking plaster, and a hood tied over her head. En route to Selkirk police station, Black said: "It was a rush of blood to the head; I hav...
#
# [23] Larry_Eyler  score=0.160
# of her client whereby Eyler would confess to his culpability in twenty further homicides committed across ten counties in Illinois and Indiana if the state of Illinois would commute his death sentence to one of life imprisonment without parole. Accor...
#
# [24] Samuel_Little  score=0.160
# for breaking into a furniture store in Lorain; he was released in 1964. By 1975, he had been arrested 26 times in eleven states for crimes including theft, assault, attempted rape, fraud, and attacks on government officials. In 1982, Little was arres...
#
# [25] Larry_Eyler  score=0.159
# Robert Little. Dobrovolskis stated this had been extremely unusual, as Little had typically returned to Terre Haute early on Sundays. Dobrovolskis further testified that in his final phone call, he had informed Eyler of his intentions to be at his ap...
#
# [26] Larry_Eyler  score=0.158
# call had been made from Little's home on the same day before the prosecutors had rested their case on April 15. Although Little had been prepared to testify in his own defense, his attorneys advised him not to do so on April 16; explaining their beli...
#
# [27] Samuel_Little  score=0.158
# said that his teenaged mother was a "lady of the night", and that she abandoned him as an infant. Soon after his birth, Little's family moved to Lorain, Ohio, where he was brought up mainly by his grandmother. He attended Hawthorne Junior High School...
#
# [28] Karl_Denke  score=0.157
# Name: Karl Denke Country: Germany Years active: 1900–1924 Proven victims: 30 Possible victims: 42+ Notes: Killed and, cannibalized, poor travelers and homeless vagrants. Kept a ledger recording his murders with at least 31 names in it (including Vinc...
#
# [29] Linda_Hazzard  score=0.157
# had succumbed to undisclosed or hitherto undiagnosed illnesses such as cancer or cirrhosis. Her opponents claimed that they all died of starvation; local residents in Olalla referred to the sanitarium as "Starvation Heights". In 1912, Hazzard was con...
#
# [30] Cleveland_Torso_Murderer  score=0.156
# Wilson. Wilson's head and arms were found in nearby bushes, while her legs would be found at Johnson's home two weeks later. Charles Sadoti, who operated a bootleg joint, identified Johnson in a line-up as being the partner of Rose Wallace, who had a...
#
# [31] Larry_Eyler  score=0.156
# an honorable man on the word of Larry Eyler?" After deliberating for over seven hours, the jury found Little not guilty of all charges on April 17. Little grinned as the verdict was read before hugging his attorney as Steven Agan's brother and parent...
#
# [32] Larry_Eyler  score=0.155
# sufficient evidence existed to charge Eyler with the December 1982 murder of Steven Agan. Upon being informed of his impending indictment in Agan's murder, Eyler agreed to voluntarily confess to his culpability, although he insisted this particular m...
#
# [33] Tsutomu_Miyazaki  score=0.155
# 7, and sexually molested their corpses. He drank the blood of one victim and ate a part of her hand. These crimes—which prior to Miyazaki's apprehension were named the "Little Girl Murders" and later the Tokyo/Saitama Serial Kidnapping Murders of Lit...
#
# [34] Igor_Chernat  score=0.155
# Name: Igor Chernat Country: Soviet Union Years active: 1985–1986 Proven victims: 4 Possible victims: 13 Notes: Known as the "Evil Spirit of Kaukjarvi"; Ukrainian soldier who raped and killed women in, Kamenka, , selling their stolen items afterwards;...
#
# [35] Larry_Eyler  score=0.155
# Robert Little in 1984. Following Eyler's arrest and conviction for the murder of Daniel Bridges, Lake County Circuit Judge William Block suffered political repercussions as a result of his decision to suppress evidence pertaining to Eyler's guilt in ...
#
# [36] Frans_Hooijmaijers  score=0.155
# Name: Frans Hooijmaijers Country: Netherlands Years active: 1970–1975 Proven victims: 5 Possible victims: 259 Notes: Nurse who was convicted for killing five patients at a hospital in, Kerkrade, , the Netherlands from 1970 to 1975, but was suspected ...
#
# [37] Larry_Eyler  score=0.155
# shouting profanities such as bitch and whore, leading many to believe Eyler was fantasizing his partner was female. By the mid-1970s, Eyler was well known within the gay community of Indianapolis—particularly among those with a leather fetish. Severa...
#
# [38] Larry_Eyler  score=0.154
# a penchant for sadomasochism, and their sexual activity frequently involved Eyler binding his partner to devices before proceeding to beat and lash him as he hurled curses at Dobrovolskis before the two engaged in penetrative sex. Although neither Ey...
#
# [39] Harold_Shipman  score=0.154
# four children. In January 2001, Chris Gregg, a senior West Yorkshire Police detective, was selected to lead an investigation into 22 of the West Yorkshire deaths. Following this, The Shipman Inquiry, submitted in July 2002, concluded that he had kill...
#
# [40] Larry_Eyler  score=0.153
# ... the reason I'm here is so that the families know, he did confess to the murders of your sons. He told me that, and I hope that can bring you some peace of mind." Eyler's posthumous confession revealed he had murdered twenty-one teenage boys and y...
#
#
# --- TF-IDF Results ---
# [1] Samuel_Little  score=0.241
# Name: Samuel Little Country: United States Years active: 1970–2005 Proven victims: 60 Possible victims: 93 Notes: Little was convicted of killing three women, but later investigations linked 31 other murders to him. He claimed he killed as many as 93...
#
# [2] Samuel_Little  score=0.128
# and 1999. The "Jane Doe" was anywhere from 15 to 50 as the details of her age and the date of her murder are unclear. She was Black, slender, wore glasses and lived in the Over-the-Rhine neighborhood of Cincinnati with a "heavy female Hispanic". Litt...
#
# [3] Samuel_Little  score=0.098
# included his confession to a previous cold case homicide in Prince George's County, Maryland, previously one of only two homicide cases in that county with unidentified victims. In December 2018, Little was indicted for strangling Linda Sue Boards, 2...
#
# [4] Cape_Town_Prostitute_Killer  score=0.084
# prostitutes wrote down the registration numbers of every vehicle that picked them up. Nevertheless, seven more victims were murdered, one of whom was 39-year-old Gloria Samuels. Samuels' corpse was found heavily decomposed with a coke bottle inside o...
#
# [5] Larry_Eyler  score=0.083
# murder, Little had suggested the two "do a scene", which he had understood to mean commit a murder for sexual pleasure as Little photographed the event with a Polaroid camera.[n 11] He and Little had lured Agan—whom Eyler had vaguely known through fr...
#
# [6] Samuel_Little  score=0.081
# and leave fewer persons to search for them. Despite the broad scope of his offending, Little was charged with and convicted of only eight murders in total as these cases had the strongest evidence of guilt: Little had a long-term girlfriend, Orelia D...
#
# [7] Samuel_Little  score=0.080
# 2014, Little was found guilty and was sentenced to life imprisonment without the possibility of parole. On the day of the verdict, Little continued to insist on his innocence. Before his death, Little was serving a sentence at California State Prison...
#
# [8] Samuel_Little  score=0.078
# of 2018, Little confessed to the 1982 murder of 55-year-old Dorothy Richards and the 1996 murder of 40-year-old Daisy McGuire; both of their bodies were found in Houma, Louisiana. On November 19, 2018, Harrison County, Mississippi, sheriff Troy Peter...
#
# [9] Samuel_Little  score=0.077
# Upon his release in February 1987, he immediately moved to Los Angeles and committed at least 10 additional murders. Little was arrested on September 5, 2012, at Wayside Christian homeless shelter in Louisville, Kentucky, and extradited to California...
#
# [10] Cape_Town_Prostitute_Killer  score=0.075
# he would order his victim to take her clothes off and then hit her in the face. Every victim had injuries on their jaws. Afterwards, he would force the victim onto his lap and strangle her to death. He then drove to a preselected spot to dump the bod...
#
# [11] Samuel_Little  score=0.068
# for breaking into a furniture store in Lorain; he was released in 1964. By 1975, he had been arrested 26 times in eleven states for crimes including theft, assault, attempted rape, fraud, and attacks on government officials. In 1982, Little was arres...
#
# [12] Larry_Eyler  score=0.068
# been too fast for his liking. Upon cross-examination, one of Little's defense attorneys, Dennis Zahn, asserted that because Little had appeared as a witness for the prosecution at Eyler's earlier trial for the murder of Daniel Bridges, he was simply ...
#
# [13] Cape_Town_Prostitute_Killer  score=0.066
# prostitutes. He also drove a blue and white bakkie, which matched the description of a vehicle that had been seen close to where Samuels' body was found. His ex-wife stated that he often disappeared for hours at a time without explaining his whereabo...
#
# [14] Larry_Eyler  score=0.066
# been murdered with the assistance of Robert Little (to whom Zellner referred in this press conference as "an unnamed individual still living in Indiana"). Zellner emphasized her client's insistence Little had been the individual who had actually murd...
#
# [15] Larry_Eyler  score=0.066
# of her client whereby Eyler would confess to his culpability in twenty further homicides committed across ten counties in Illinois and Indiana if the state of Illinois would commute his death sentence to one of life imprisonment without parole. Accor...
#
# [16] Samuel_Little  score=0.059
# said that his teenaged mother was a "lady of the night", and that she abandoned him as an infant. Soon after his birth, Little's family moved to Lorain, Ohio, where he was brought up mainly by his grandmother. He attended Hawthorne Junior High School...
#
# [17] Larry_Eyler  score=0.056
# call had been made from Little's home on the same day before the prosecutors had rested their case on April 15. Although Little had been prepared to testify in his own defense, his attorneys advised him not to do so on April 16; explaining their beli...
#
# [18] Larry_Eyler  score=0.054
# Robert Little. Dobrovolskis stated this had been extremely unusual, as Little had typically returned to Terre Haute early on Sundays. Dobrovolskis further testified that in his final phone call, he had informed Eyler of his intentions to be at his ap...
#
# [19] Larry_Eyler  score=0.047
# an honorable man on the word of Larry Eyler?" After deliberating for over seven hours, the jury found Little not guilty of all charges on April 17. Little grinned as the verdict was read before hugging his attorney as Steven Agan's brother and parent...
#
# [20] Larry_Eyler  score=0.046
# sufficient evidence existed to charge Eyler with the December 1982 murder of Steven Agan. Upon being informed of his impending indictment in Agan's murder, Eyler agreed to voluntarily confess to his culpability, although he insisted this particular m...
#
# [21] Larry_Eyler  score=0.045
# October 1, investigators from CIMAIT obtained a search warrant authorizing their search of the Terre Haute home of Robert Little. This search was conducted at dawn on October 2 and revealed further circumstantial evidence, such as credit card receipt...
#
# [22] Larry_Eyler  score=0.044
# Robert Little in 1984. Following Eyler's arrest and conviction for the murder of Daniel Bridges, Lake County Circuit Judge William Block suffered political repercussions as a result of his decision to suppress evidence pertaining to Eyler's guilt in ...
#
# [23] Larry_Eyler  score=0.043
# shouting profanities such as bitch and whore, leading many to believe Eyler was fantasizing his partner was female. By the mid-1970s, Eyler was well known within the gay community of Indianapolis—particularly among those with a leather fetish. Severa...
#
# [24] Sergey_Shipilov  score=0.041
# Office of the Arkhangelsk Oblast, were unsuccessful in their investigation into the disappearing women. Nevertheless, one day they noticed Shipilov's honeywagon pass by a place where one of the victims had disappeared. Investigators learned that a ho...
#
# [25] Larry_Eyler  score=0.041
# before stating: "This is the [most extensively mutilated body] I've seen without the body being cut into pieces." Pless testified that many of the beating, stabbing, and slashing injuries had been inflicted after Agan was already deceased, although n...
#
# [26] Samuel_Little  score=0.039
# problems, and other health conditions. Jillian Lauren investigated Little and interviewed him at length in prison. Lauren initially had begun writing a mystery novel, and while interviewing detective Mitzi Roberts of the Los Angeles Police Department...
#
# [27] Andrei_Chikatilo  score=0.039
# September 1982, he killed a further five victims between the ages of 9 and 18. He established a pattern of approaching children, runaways, and young vagrants at bus or railway stations, enticing them to a nearby forest or other secluded area, and kil...
#
# [28] Toregeldy_Zharambaev  score=0.038
# a local woman and had a son with her. The family lived with Zharambaev's parents, who frequently criticized him for not working and living off of his relatives. By the late 1980s, Zharambaev's aggressive outbursts worsened, and by the onset of 1990, ...
#
# [29] Monster_of_Udine  score=0.038
# Name: Monster of Udine Country: Italy Years active: 1980–1989 Proven victims: 4 Possible victims: 4+ Notes: Killed at least 4 victims in the, Province of Udine, ,, Italy, ., [, 362, ] The Monster of Udine (Italian: Mostro di Udine) was an unidentifie...
#
# [30] Andrei_Chikatilo  score=0.037
# as the woman had been killed with a slab of concrete, had not been disembowelled, and her murderer had not wounded her eyes or genitals, investigators were unsure whether to link this murder to the investigation. In May, Chikatilo killed a 9-year-old...
#
# [31] Robert_Black  score=0.037
# his daughter inside, her wrists bound behind her back, her legs tied together, her mouth bound and gagged with sticking plaster, and a hood tied over her head. En route to Selkirk police station, Black said: "It was a rush of blood to the head; I hav...
#
# [32] Samuel_Little  score=0.037
# a bar near East 105th and Euclid Avenues. He described her as a short, plump woman in her twenties with brown hair. Little confessed to killing another Cleveland woman in 1977 or 1978. The woman murdered in 1977 or 1978 was found on March 18, 1983, i...
#
# [33] Larry_Eyler  score=0.035
# witness for the prosecution. Schippers had informed Judge Urso he was offering his legal services free of charge; adding he would inform the court if these circumstances changed. As such, the appeal contended Schippers had been guilty of attorney mis...
#
# [34] Cedric_Maake  score=0.034
# Name: Cedric Maake Country: South Africa Years active: 1996–1997 Proven victims: 27 Possible victims: 35+ Notes: Known as the "Wemmer Pan Killer" and "Hammer Killer". He killed his victims with different instruments such as guns, rocks, a knife, and ...
#
# [35] Petr_Zelenka  score=0.033
# Name: Petr Zelenka Country: Czech Republic Years active: 2006 Proven victims: 7 Possible victims: 21, [, 436, ], [, title missing, ] Notes: Killed his victims with a, lethal injection, of, heparin, from May to September 2006. Ten people survived his ...
#
# [36] Andrei_Chikatilo  score=0.032
# The intensity of the manhunt in the years up to 1984 had receded to a degree between 1985 and 1987, when Chikatilo had committed only three murders investigators had conclusively linked to the killer—all killed by 1986. However, by March 1990, a furt...
#
# [37] Mikhail_Novosyolov  score=0.032
# Name: Mikhail Novosyolov Country: Soviet Union, Russia, Tajikistan Years active: 1977–1995 Proven victims: 22 Possible victims: 22 Notes: Known as the ", Necrophile, Rebel"; killed his victims with blows from heavy objects, then had sexual intercours...
#
# [38] Jeff_Davis_8  score=0.032
# in too advanced state of decomposition to determine the cause of death, though asphyxia is a suspected cause of death. Ethan Brown's book Murder in the Bayou alleged that there were close connections between the victims, suspects, and investigators. ...
#
# [39] Vladyslav_Volkovich_and_Volodymyr_Kondratenko  score=0.032
# so they decided to practice on the homeless. They reportedly killed at least five before risking to attack a more dangerous target. They eventually settled on attacking car owners; owning a personal vehicle was a considerable luxury and a sign of wea...
#
# [40] Abul_Djabar  score=0.031
# Name: Abul Djabar Country: Afghanistan Years active: 1970 and earlier Proven victims: 65 Possible victims: 300+ Notes: Killed 65 men and boys by strangling them with turbans while raping them. Suspected of over 300 murders. Sentenced to death and han...

# %% [markdown]
# ###RE-RANKING with cross-encoder:

# %%
# Load cross-encoder reranker
reranker = CrossEncoder("cross-encoder/ms-marco-MiniLM-L-6-v2", device=my_device)
# Out:
# config.json:   0%|          | 0.00/794 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/132 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]

# %%
# CROSS-ENCODER RERANKING

# 1. Prepare pairs for the Cross-Encoder
# We keep a reference to the 'points' so we don't lose the metadata
points = raw_embeddings_results.points
texts = [p.payload.get("text", "") for p in points]
pairs = [(query_sample, t) for t in texts]

# 2. Predict scores
if texts:
    scores = reranker.predict(pairs)

    # 3. Sort the point based on the scores (High to Low)
    # zip(points, scores) keeps the metadata attached to the score
    ranked_points = sorted(list(zip(points, scores)), key=lambda x: x[1], reverse=True)

    print("\n--- Cross-Encoder Reranking Results ---")
    nof_keep_sentences = 20

    # We will store the full top-k points here for the RAG step
    top_reranked_points = []

    seen_names = set() # Track names we have seen

    for point, score in ranked_points:

        name = point.payload.get("name", "Unknown")

        # SKIP if we have already seen this name
        if name in seen_names:
            continue

        # Add to set and final list
        seen_names.add(name)

        # Convert logit score to probability (0-1) for display
        normalized = 1 / (1 + np.exp(-score))

        c_val = point.payload.get("country", [])
        c_str = ", ".join(c_val) if isinstance(c_val, list) else str(c_val)
        text_preview = point.payload.get("text", "")[:100].replace("\n", " ")

        print(f"[{len(top_reranked_points) + 1}] {name} ({c_str}) | Score: {normalized:.3f}")
        print(f"  Snippet: {text_preview}...")
        print()

        top_reranked_points.append(point)

        # Stop once we have enough unique items
        if len(top_reranked_points) >= nof_keep_sentences:
            break

    print(f"Selected top {len(top_reranked_points)} unique results for RAG context.")

else:
    print("No results to rerank.")
    top_reranked_points = []
# Out:
# --- Cross-Encoder Reranking Results ---
# [1] Samuel_Little (United States) | Score: 0.999
#   Snippet: Name: Samuel Little Country: United States Years active: 1970–2005 Proven victims: 60 Possible victi...
#
# [2] Cape_Town_Prostitute_Killer (South Africa) | Score: 0.995
#   Snippet: he would order his victim to take her clothes off and then hit her in the face. Every victim had inj...
#
# [3] Larry_Eyler (United States) | Score: 0.980
#   Snippet: been too fast for his liking. Upon cross-examination, one of Little's defense attorneys, Dennis Zahn...
#
# [4] Andrei_Chikatilo (Soviet Union) | Score: 0.938
#   Snippet: September 1982, he killed a further five victims between the ages of 9 and 18. He established a patt...
#
# [5] Fritz_Haarmann (Germany) | Score: 0.676
#   Snippet: to Haarmann, he never actually intended to murder any of his victims, but would be seized by an irre...
#
# [6] Clementine_Barnabet (United States) | Score: 0.217
#   Snippet: of the victims. Every victim was slashed or bludgeoned with an ax, which was the cause of death for ...
#
# [7] William_Unek (Belgian Congo, Tanganyika) | Score: 0.090
#   Snippet: stabbed another one, strangled a teenage girl, and burned two women and a child. The coroner's state...
#
# [8] Philipp_Tyurin (Soviet Union) | Score: 0.079
#   Snippet: in the dead of night. The first murder he committed was in April 1945. All of the murders, as Tyurin...
#
# [9] William_Bonin (United States) | Score: 0.033
#   Snippet: it surprised me that I did it. I stabbed him again and then again, and again and again until he was ...
#
# [10] Cleveland_Torso_Murderer (United States) | Score: 0.027
#   Snippet: known victims were killed between 1935 and 1938. Some investigators, including lead detective Peter ...
#
# [11] Francisco_das_Chagas_Rodrigues_de_Brito (Brazil) | Score: 0.022
#   Snippet: mechanic. The suspect was arrested on suspicion of killing Jonahtan, and 16 other boys, leading inve...
#
# [12] John_Justin_Bunting__Robert_Joe_Wagner_and_James_Spyridon_Vlassakis (Australia) | Score: 0.017
#   Snippet: Some were befriended for a short time and pulled into the group as easy targets for Bunting. Kevin H...
#
# [13] Briley_Brothers (United States) | Score: 0.015
#   Snippet: they left, a lit match was tossed on the fuel. The two hurriedly packed their stolen loot – a televi...
#
# [14] Michael_Swango (United States, Zimbabwe) | Score: 0.005
#   Snippet: sentencing hearing, Swango admitted to causing three murders, lying about his role in causing a four...
#
# [15] Robert_Black (United Kingdom, Ireland, , West Germany, , Netherlands, , France) | Score: 0.003
#   Snippet: counsel had fundamentally objected to. Black also contended that the final instructions delivered to...
#
# [16] Jerry_Brudos (United States) | Score: 0.001
#   Snippet: the process. Hours later, Brudos severed Slawson's left foot from her body with a hacksaw; he retain...
#
# [17] Belle_Gunness (United States) | Score: 0.000
#   Snippet: When Lamphere was arrested, he was wearing John Moe's overcoat and Henry Gurholt's watch. Edward Bec...
#
# Selected top 17 unique results for RAG context.

# %% [markdown]
# ### RAG with Reranking

# %%
# COMPLETE RAG IMPLEMENTATION WITH HYBRID FILTERING & STRUCTURED METADATA

# ---------- SETUP: Qwen LLM Model ----------
print("Setting up Qwen model for RAG...")

# Initialize HuggingFace client
llm_model = "Qwen/Qwen2.5-72B-Instruct"
client_llm = InferenceClient(llm_model, token=os.getenv("HF_TOKEN"))

# System instructions
system_instructions = (
    "You are a factual assistant specializing in crime statistics. "
    "Use the structured data provided (name, proven_victims, country, text) to answer accurately. "
    "When discussing victim counts, cite the exact numbers from the 'proven_victims' field. "
    "Keep answers concise (150 words max). Start with 'Hello!'"
)

print(f"Qwen model initialized: {llm_model}")
print("="*60 + "\n")

# RETRIEVAL WITH HYBRID FILTERING
print("Performing hybrid search (semantic + numeric filtering)...")

# We use the raw_embeddings_results because we need the full Payload objects
raw_embeddings_results, formatted_embeddings_results = hybrid_qdrant_search(
    client,
    "serial_killers",
    query_sample,
    my_question_embedding,
    top_k=50  # Retrieve more, then rerank to top 10
)

print(f"Found {len(raw_embeddings_results.points)} results with hybrid filtering")
print("="*60 + "\n")

# ---------- CROSS-ENCODER RERANKING (With Deduplication) ----------
print("Reranking results with cross-encoder...")

# 1. Get the points and their texts
points = raw_embeddings_results.points
texts = [p.payload.get("text", "") for p in points]

if texts:
    # 2. Score the pairs
    pairs = [(query_sample, t) for t in texts]
    scores = reranker.predict(pairs)

    # 3. ZIP the POINT object with the SCORE
    ranked_points = sorted(list(zip(points, scores)), key=lambda x: x[1], reverse=True)

    print(f"\n--- Cross-Encoder Reranking Results (Top Unique) ---")

    # --- DEDUPLICATION LOGIC ---
    nof_keep_sentences = 10
    top_context_points = []
    seen_names = set()

    for point, score in ranked_points:
        # Get the name
        name = point.payload.get("name", "Unknown")

        # IF we have already seen this killer, SKIP this chunk
        if name in seen_names:
            continue

        # OTHERWISE, add to our final list
        seen_names.add(name)
        top_context_points.append(point)

        # Visualization (Optional)
        normalized = 1 / (1 + np.exp(-score))
        snippet = point.payload.get("text", "")[:100].replace("\n", " ")
        print(f"[{len(top_context_points)}] {name} | Score: {normalized:.3f}")
        print(f"    {snippet}...")
        print()

        # Stop once we have found 10 UNIQUE killers
        if len(top_context_points) >= nof_keep_sentences:
            break

    print(f"Selected {len(top_context_points)} unique killers for RAG context.")
else:
    top_context_points = []
    print("No texts found for reranking.")

print("="*60 + "\n")


# ---------- CREATE STRUCTURED CONTEXT WITH METADATA ----------
print("Creating structured context with metadata...\n")

context_parts = []

if top_context_points:
    for i, point in enumerate(top_context_points):
        payload = point.payload

        # 1. Handle Country List Display
        c_val = payload.get("country", "Unknown")
        if isinstance(c_val, list):
            country_str = ", ".join(c_val)
        else:
            country_str = str(c_val)

        # 2. Build the structured block
        context_part = f"[SERIAL KILLER {i+1}]\n"
        context_part += f"Name: {payload.get('name', 'Unknown')}\n"
        context_part += f"Country: {country_str}\n"
        context_part += f"Proven victims: {payload.get('proven_victims', 'Unknown')}\n"

        possible = payload.get('possible_victims')
        if possible:
            context_part += f"Possible victims: {possible}\n"

        context_part += f"Details: {payload.get('text', '')}\n"

        context_parts.append(context_part)

    context = "\n\n".join(context_parts)

    augmented_prompt = (
        f"STRUCTURED CRIME DATA:\n\n"
        f"{context}\n\n"
        f"QUESTION: {query_sample}\n\n"
        f"INSTRUCTIONS:\n"
        f"1. Answer based ONLY on the structured data above\n"
        f"2. When mentioning victim counts, use the exact 'Proven victims' numbers\n"
        f"3. Only mention the killer's name if the user's question specifically asks for name or names\n"
        f"4. Only mention the Country if the user's question specifically asks for location, origin, or limits by geography. Otherwise, do not mention the country\n"
        f"5. Only mention the victim counts (proven or possible) if the user's question specifically asks for numbers, statistics, ranking (e.g. 'top', 'worst'), or severity. Otherwise, do not mention the victim counts.\n"
        f"6. If the user asks for a summary, overview, or explanation of patterns: Provide a synthesized paragraph explaining the commonalities, behaviors, or trends found in the context. Do NOT just list names.\n"
        f"7. If the user asks for a definition: Define the term clearly based on the context provided.\n"
        f"8. Be concise and factual"
    )

    print("Created structured context.")
else:
    augmented_prompt = query_sample
    print("No context available, using query directly")

print("="*60 + "\n")

# ---------- RAG GENERATION ----------
max_tokens = 300
temperature = 0.7

messages = [
    {"role": "system", "content": system_instructions},
    {"role": "user", "content": augmented_prompt}
]

print("Generating response with Qwen...")
try:
    completion = client_llm.chat_completion(
        messages=messages,
        max_tokens=max_tokens,
        temperature=temperature,
        stream=False
    )

    answer = completion.choices[0].message["content"]

    print("="*60)
    print("🤖 QWEN RESPONSE:")
    print("="*60)
    print(answer)
    print("="*60 + "\n")

except Exception as e:
    print(f"Error: {e}")
# Out:
# Setting up Qwen model for RAG...
# Qwen model initialized: Qwen/Qwen2.5-72B-Instruct
# ============================================================
#
# Performing hybrid search (semantic + numeric filtering)...
# Found 50 results with hybrid filtering
# ============================================================
#
# Reranking results with cross-encoder...
#
# --- Cross-Encoder Reranking Results (Top Unique) ---
# [1] Samuel_Little | Score: 0.999
#     Name: Samuel Little Country: United States Years active: 1970–2005 Proven victims: 60 Possible victi...
#
# [2] Cape_Town_Prostitute_Killer | Score: 0.995
#     he would order his victim to take her clothes off and then hit her in the face. Every victim had inj...
#
# [3] Larry_Eyler | Score: 0.980
#     been too fast for his liking. Upon cross-examination, one of Little's defense attorneys, Dennis Zahn...
#
# [4] Andrei_Chikatilo | Score: 0.938
#     September 1982, he killed a further five victims between the ages of 9 and 18. He established a patt...
#
# [5] Fritz_Haarmann | Score: 0.676
#     to Haarmann, he never actually intended to murder any of his victims, but would be seized by an irre...
#
# [6] M__Jaishankar | Score: 0.406
#     unsuccessfully tried to effect another escape from the Bangalore Central Prison. After this plot fai...
#
# [7] Dean_Corll_____David_Owen_Brooks__and__Elmer_Wayne_Henley | Score: 0.379
#     in February 1971. The enticement was typically an offer of a party or a lift, and the victim would b...
#
# [8] Clementine_Barnabet | Score: 0.217
#     of the victims. Every victim was slashed or bludgeoned with an ax, which was the cause of death for ...
#
# [9] Viktor_Sayenko_and_Igor_Suprunyuk | Score: 0.176
#     Thirteen more murders followed, often with multiple bodies found on the same day. In addition to the...
#
# [10] William_Unek | Score: 0.090
#     stabbed another one, strangled a teenage girl, and burned two women and a child. The coroner's state...
#
# Selected 10 unique killers for RAG context.
# ============================================================
#
# Creating structured context with metadata...
#
# Created structured context.
# ============================================================
#
# Generating response with Qwen...
# ============================================================
# 🤖 QWEN RESPONSE:
# ============================================================
# Hello! Samuel Little killed his victims through various methods, primarily strangulation and blunt force trauma. He would often lure his victims, predominantly women, to secluded areas where he would overpower them. Little's modus operandi included beating his victims, sometimes severely, and strangling them to death. He confessed to additional methods, including the use of ligatures and knives, though the specific details of these methods were not consistently detailed in his confessions. The FBI confirmed his involvement in at least 60 murders, making him one of the most prolific serial killers in American history.
# ============================================================

# %%
# Re-initialize the Qdrant client
client = QdrantClient(url=QDRANT_URL, api_key=API_KEY)

# ---------- Evaluation loop ----------
evaluation_questions = [
    "Who is Mariam Soulakiotis?",
    "What crimes did Karl Denke commit?",
    "Tell me something about Carl Eugene Watts.",
    "What is known about Joachim Georg Kroll?",
    "Give me a general summary about serial killers who murder mostly young boys."
]

# Settings
nof_keep_sentences = 10
evaluation_results = []

print(f"Starting evaluation on {len(evaluation_questions)} questions...")

for question in evaluation_questions:
    print(f"\nProcessing: {question}")
    print('-'*60)

    # 1. PREPROCESS QUERY
    clean_q = minimal_clean(question)
    question_embedding = embeddings_model.encode([clean_q])[0].tolist()

    # 2. HYBRID SEARCH (Retrieval)
    # Fetch 50 candidates to ensure we have enough for deduplication
    raw_results, _ = hybrid_qdrant_search(
        client,
        "serial_killers",
        question,
        question_embedding,
        top_k=50
    )

    # 3. RERANKING & DEDUPLICATION
    points = raw_results.points
    texts = [p.payload.get("text", "") for p in points]

    top_context_points = []

    if texts:
        # Score pairs
        pairs = [(question, t) for t in texts]
        scores = reranker.predict(pairs)

        # Sort by Score
        ranked_points = sorted(list(zip(points, scores)), key=lambda x: x[1], reverse=True)

        # --- DEDUPLICATION LOGIC ---
        seen_names = set()

        for point, score in ranked_points:
            name = point.payload.get("name", "Unknown")

            # Skip duplicates
            if name in seen_names:
                continue

            seen_names.add(name)
            top_context_points.append(point)

            # Stop when we have enough unique killers
            if len(top_context_points) >= nof_keep_sentences:
                break
    else:
        print("   Warning: No results found.")

    # 4. BUILD STRUCTURED CONTEXT
    context_parts = []
    for i, point in enumerate(top_context_points):
        p = point.payload

        # Handle Country List
        c_val = p.get("country", "Unknown")
        c_str = ", ".join(c_val) if isinstance(c_val, list) else str(c_val)

        block = (
            f"[SERIAL KILLER {i+1}]\n"
            f"Name: {p.get('name', 'Unknown')}\n"
            f"Country: {c_str}\n"
            f"Proven victims: {p.get('proven_victims', 'Unknown')}\n"
            f"Details: {p.get('text', '')[:500]}...\n"
        )
        context_parts.append(block)

    context_str = "\n\n".join(context_parts)

    # 5. BUILD PROMPT
    if context_str:
        augmented_prompt = (
            f"STRUCTURED CRIME DATA:\n\n"
            f"{context_str}\n\n"
            f"QUESTION: {question}\n\n"
            f"INSTRUCTIONS:\n"
            f"1. Answer based ONLY on the structured data above\n"
            f"2. When mentioning victim counts, use the exact 'Proven victims' numbers\n"
            f"3. Only mention the killer's name if the user's question specifically asks for name or names\n"
            f"4. Only mention the Country if the user's question specifically asks for location, origin, or limits by geography. Otherwise, do not mention the country\n"
            f"5. Only mention the victim counts (proven or possible) if the user's question specifically asks for numbers, statistics, ranking (e.g. 'top', 'worst'), or severity. Otherwise, do not mention the victim counts.\n"
            f"6. If the user asks for a summary, overview, or explanation of patterns: Provide a synthesized paragraph explaining the commonalities, behaviors, or trends found in the context. Do NOT just list names.\n"
            f"7. If the user asks for a definition: Define the term clearly based on the context provided.\n"
            f"8. Be concise and factual"
        )
    else:
        augmented_prompt = question # Fallback if no context found

    messages = [
        {"role": "system", "content": "You are a factual assistant specializing in crime statistics."},
        {"role": "user", "content": augmented_prompt}
    ]

    # 6. GENERATE WITH QWEN
    try:
        completion = client_llm.chat_completion(
            messages=messages,
            max_tokens=300,
            temperature=0.7,
            stream=False
        )
        answer = completion.choices[0].message["content"]
        print(f"Answer: {answer}\n")
    except Exception as e:
        answer = f"Error: {e}"
        print(f"Generation Failed: {e}")

    # 7. LOG RESULTS
    evaluation_results.append({
        "Question": question,
        "Retrieved Context": context_str,
        "Generated Answer": answer
    })

# Save results
df_eval_reranked = pd.DataFrame(evaluation_results)
df_eval_reranked.to_csv("rag_evaluation_results_reranked_qwen.csv", index=False)
print("Exported results to rag_evaluation_results_reranked_qwen.csv")
# Out:
# Starting evaluation on 5 questions...
#
# Processing: Who is Mariam Soulakiotis?
# ------------------------------------------------------------
# Answer: Mariam Soulakiotis was an individual known as "Mother Rasputin," an abbess who was convicted of murdering 177 individuals. She operated an abbey where she fraudulently offered free tuberculosis treatment, but the treatments were ineffective and often harmful, leading to the deaths of many of her victims. The true extent of her crimes remains uncertain, with estimates suggesting that the number of victims could be much higher, possibly exceeding 500. Her modus operandi involved targeting wealthy women and children who sought refuge or medical help at her abbey.
#
#
# Processing: What crimes did Karl Denke commit?
# ------------------------------------------------------------
# Answer: Karl Denke killed and cannibalized poor travelers and homeless vagrants. He kept a ledger recording his murders, which included at least 31 names, confirming at least 30 proven victims. Due to the extensive human remains found in his apartment, it is suspected that his victim count might exceed 42.
#
#
# Processing: Tell me something about Carl Eugene Watts.
# ------------------------------------------------------------
# Answer: Carl Eugene Watts officially confessed to the murders of thirteen women but later claimed he had killed forty women and also implied that there were more than eighty victims in total. He avoided confessing to all these murders outright, stating he did not want to be seen as a "mass murderer." Police consider Watts a suspect in ninety unsolved murders, and he is now suspected to have killed more than one hundred.
#
#
# Processing: What is known about Joachim Georg Kroll?
# ------------------------------------------------------------
# Answer: Joachim Georg Kroll was active from 1955 to 1976 and was known as the "Ruhr Cannibal" and "The Duisburg Man-Eater." He was convicted of murdering a minimum of eight women and young girls in the Ruhr metropolitan region. Kroll died from a heart attack in prison in 1991.
#
#
# Processing: Give me a general summary about serial killers who murder mostly young boys.
# ------------------------------------------------------------
# Answer: Serial killers who predominantly target young boys exhibit a pattern of preying on vulnerable and often defenseless victims. These killers typically operate over extended periods, allowing them to accumulate multiple victims. Their methods often involve sexual assault and torture, reflecting a deep-seated pathology focused on power and control. Many of these killers have backgrounds marked by social isolation or personal trauma, which may contribute to their deviant behavior. The crimes are often discovered through the discovery of multiple bodies or through confessions, and the killers are frequently caught due to their escalating boldness or mistakes. Despite the varied locations and times in which they operated, these serial killers share a common thread of exploiting the innocence and trust of their young male victims.
#
# Exported results to rag_evaluation_results_reranked_qwen.csv

# %%
# Optionally save the file to local environment
files.download("rag_evaluation_results_reranked_qwen.csv")

# %% [markdown]
# ##Streamlit Interface
